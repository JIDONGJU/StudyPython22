# %% [markdown]
# ### 그래프 그리기
# #### 데이터 시각화 필요한 이유
# #### matplotlib 사용하기
# #### seaborn 사용하기
# #### 데이터프레임과 시리즈로 그래프 그리기

# %% [markdown]
# #### 데이터 시각화 필요한 이유

# %% [markdown]
# #### 앤스콤 데이터 불러온 후 그래프 그리기

# %%
import seaborn as sns

anscombe = sns.load_dataset('anscombe')
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
dataset1 = anscombe[anscombe['dataset'] == 'I']

# %%
plt.plot(dataset1['x'], dataset1['y'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(dataset1['x'], dataset1['y'], 'o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### 한번에 4개의 그래프 그리기

# %%
dataset2 = anscombe[anscombe['dataset'] == 'II']
dataset3 = anscombe[anscombe['dataset'] == 'III']
dataset4 = anscombe[anscombe['dataset'] == 'IV']

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2,2,1) # 2 x 2 격자 중 1번
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes1.plot(dataset1['x'],dataset1['y'], 'o') # 그래프 그리기
axes2.plot(dataset2['x'],dataset2['y'], 'o')
axes3.plot(dataset3['x'],dataset3['y'], 'o')
axes4.plot(dataset4['x'],dataset4['y'], 'o')

# %%
axes1.set_title('dataset1') # 제목 추가
axes2.set_title('dataset2')
axes3.set_title('dataset3')
axes4.set_title('dataset4')
# Out:
# Text(0.5, 1.0, 'dataset4')

# %%
fig.tight_layout() # 레이아웃 조절

# %% [markdown]
# #### matplotlib 자유롭게 사용하기

# %% [markdown]
# #### 기초 그래프 그리기 - 히스토그램, 산점도, 박스

# %%
tips = sns.load_dataset('tips')
print(tips.head())
print(type('tips'))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'str'>

# %% [markdown]
# #### 히스토그램

# %%
fig = plt.figure()
axes1 = fig.add_subplot(1,1,1)
axes1.hist(tips['total_bill'],bins=10, color='gray')
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total bill')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Total bill')

# %% [markdown]
# #### 산점도그래프

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'], tips['tip'])
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Tip')

# %% [markdown]
# #### Boxplot

# %%
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1,1,1)

axes1.boxplot([tips[tips['sex'] == 'Female']['tip'],
              tips[tips['sex'] == 'Male']['tip']],
             labels=['Female', 'Male'])

axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %% [markdown]
# #### 다변량 데이터로 다변랑 그래프 그리기 - 산점도 그래프

# %%
def recode_sex(sex):
    if sex == 'Female':
        return 0
    else:
        return 1

tips['sex_color'] = tips['sex'].apply(recode_sex)

scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x=tips['total_bill'],
    y=tips['tip'],
    s=tips['size']*10,
    c=tips['sex_color'],
    alpha = 0.5)
axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Tip')

# %% [markdown]
# #### Barplot

# %%
bar_plot = plt.figure()
axes1 = bar_plot.add_subplot(1,1,1)
axes1.bar(tups['sex'],tips['total_bill'])
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 3>()
#       1 bar_plot = plt.figure()
#       2 axes1 = bar_plot.add_subplot(1,1,1)
# ----> 3 axes1.bar(tups['sex'],tips['total_bill'])
#
# NameError: name 'tups' is not defined

# %% [markdown]
# ### seaborn 라이브러리 자유롭게 사용하기

# %% [markdown]
# #### 단변량 그래프 그리기 - 히스토그램

# %%
import seaborn as sns
tips = sns.load_dataset('tips')

ax = plt.subplots()
ax = sns.distplot(tips['total_bill'])
ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %%
# 밀집도 그래프를 제외하려면 kde = False
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], kde = False)
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %%
# 밀집도 그래프만 나타내려면 hist = False
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], hist = False)
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], rug=True)
ax.set_title('Total Bill Histogram with Density and Rug Plot')
ax.set_xlabel('Total Bill')
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Total Bill')

# %%
ax = plt.subplots()
ax = sns.countplot('day', data = tips)
ax.set_title('Count of days')
ax.set_xlabel('Day of the week')
ax.set_ylabel('Frequency')
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# #### 산점그래프에 회귀선 그리기

# %%
ax = plt.subplots()
ax = sns.regplot(x = 'total_bill', y = 'tip', data = tips)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')

ax = plt.subplot()
ax = sns.regplot(x = 'total_bill', y = 'tip', data = tips)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Tip')

# %% [markdown]
# #### jointplot

# %%
joint = sns.jointplot(x='total_bill', y='tip', data = tips)
joint.set_axis_labels(xlabel='Total bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %% [markdown]
# #### 육각그래프 joint

# %%
hexbin = sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')
hexbin.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Tip')

# %% [markdown]
# #### 이차원 밀집도

# %%
ax = plt.subplots()
ax = sns.kdeplot(data=tips['total_bill'],
                data2=tips['tip'],
                shade=True)
ax.set_title('Kernel Densiti Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:1681: FutureWarning: Use `x` and `y` rather than `data` `and `data2`
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Tip')

# %% [markdown]
# #### 바그래프

# %%
ax = plt.subplots()
ax = sns.barplot(x='time', y='total_bill', data=tips)
ax.set_title('Bar Plot')
ax.set_xlabel('Time of day')
ax.set_ylabel('Average total bill')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Average total bill')

# %%
ax = plt.subplots()
ax = sns.boxplot(x='time', y='total_bill', data=tips)
ax.set_title('Boxplot')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# #### 박스 그래프에 커널 밀도를 추정한 바이올린 그래프

# %%
ax = plt.subplot()
ax = sns.violinplot(x='time', y='total_bill', data=tips)
ax.set_title('Violin')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# Text(46.972222222222214, 0.5, 'Total Bill')

# %% [markdown]
# #### 관계그래프

# %%
fig = sns.pairplot(tips)
# Out:
# <img src="data:image/png;base64,..." width="750">

# %%
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pair_grid = pair_grid.map_diag(sns.distplot, rug=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="750">
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %% [markdown]
# #### 다변량 그래프 그리기

# %%
ax = plt.subplots()
ax = sns.violinplot(x='시간', y='총 금액', hue='sex', data=tips, split=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_6888\742676005.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   ax = plt.subplots()
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [72], in <cell line: 2>()
#       1 ax = plt.subplots()
# ----> 2 ax = sns.violinplot(x='시간', y='총 금액', hue='sex', data=tips, split=True)
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
# ...

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=False)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
fig = sns.pairplot(tips, hue='sex')
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\axisgrid.py:1242: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)
# <img src="data:image/png;base64,..." width="850">

# %% [markdown]
# #### 산점도 그래프의 크기와 모양 조절

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips,
                    fit_reg = False,
                    hue = 'sex',
                    scatter_kws = {'s':tips['size']*10})
# Out:
# <img src="data:image/png;base64,..." width="500">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [77], in <cell line: 1>()
# ----> 1 scatter = sns.lmplot(x='total_bill', y='tip', data=tips,
#       2                     fit_reg = False,
#       3                     hue = 'sex',
#       4                     scatter_kws = {'s':tips['size']*10})
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...
