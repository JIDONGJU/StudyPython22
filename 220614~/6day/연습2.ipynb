# %% [markdown]
# ##### 1. for문을 이용하여 files_org 폴더 내의 파일 모두 불러와서 df_dict에 넣기
# ##### 2. for문을 이용하여 df_dict의 key값과 value값을 new_dick에 넣기
# ##### 3. for문을 이용하여 파일 저장하기

# %%
import pandas as pd

# %%
# Hint
# 4개 데이터 기준값
nm_list = ['20','30','40','53']

# 4개 엑셀 시트 기준값
sheep_list = ['20table_명세서일반내역',
              '30tabel_진료내역',
              '40table_상병',
              '53table_처방전상세내역']

# 4개의 데이터프레임 저장
df_dict = {}

# 4개의 시트 조회값 저장
df_col_dict = {}

# %%
nm_list = ['20','30','40','53']
sheep_list = ['20table_명세서일반내역',
              '30table_진료내역',
              '40table_상병',
              '53table_처방전상세내역']
df_dict = {}
df_col_dict = {}
path = './files_org/표본자료 변수 테이블(2012-2013).xlsx'

for i in range(0, len(nm_list), 1):
    df_dict[nm_list[i]] = pd.read_csv('./files_org/SAMPLE_DB_{}TABLE_2013.txt'.format(nm_list[i], sep=","))
    df_col_dict[nm_list[i]] = pd.read_excel(path, sheet_name=sheep_list[i], usecols="A,D")
    new_dict = {}

    for j in range(0, len(df_col_dict[nm_list[i]])):
        new_dict[df_col_dict[nm_list[i]].to_dict("records")[j]["변수명"]] = \
        df_col_dict[nm_list[i]].to_dict("records")[j]["표준한글컬럼명"]

    df_col_dict[nm_list[i]].rename(columns = new_dict).to_excel('./files_new2/df_{}table_kor.xlsx'.format(sheep_list[i]), index=False)
# Out:
# {'20':                     변수명     표준한글컬럼명
# 0                   key    명세서 연결코드
# 1             DMD_TP_CD      청구구분코드
# 2            DMD_FRM_CD      청구형태코드
# 3                FOM_CD        서식코드
# 4                    no     수진자고유번호
# 5                   AGG         연령군
# 6         SelectionProb        추출확률
# 7        SamplingWeight       샘플가중치
# 8               PAT_AGE       수진자연령
# 9             SEX_TP_CD      성별구분코드
# 10          INSUP_TP_CD       보험자코드
# 11             MSICK_CD       주상병코드
# 12             SSICK_CD       부상병코드
# 13           RECU_FR_DD      요양개시일자
# 14           RECU_TO_DD      요양만료일자
# 15         DGRSLT_TP_CD    진료결과구분코드
# 16            DGSBJT_CD      진료과목코드
# 17           DMD_DRG_NO     청구DRG번호
# 18          FST_IPAT_DD      최초입원일자
# 19  IPAT_ARIV_PTH_TP_CD  입원도착경로구분코드
# 20           OINJ_TP_CD      공상구분코드
# 21           RECU_DDCNT        요양일수
# 22            VST_DDCNT        내원일수
# 23     RVD_RPE_TAMT_AMT  심결요양급여비용총액
# 24     RVD_SLF_BRDN_AMT     심결본인부담금
# 25   RVD_INSUP_BRDN_AMT    심결보험자부담금
# 26              SOPR_YN        수술여부
# 27       PRCL_SYM_TP_CD    특정기호구분코드
# 28            MAIDCL_CD    의료급여종별코드
# 29         RADT_DIAG_YN     방사선진단여부
# 30         RADT_TRET_YN     방사선치료여부
# 31                  yno   요양기관 고유번호}
# {'20':                     변수명     표준한글컬럼명
# 0                   key    명세서 연결코드
# 1             DMD_TP_CD      청구구분코드
# 2            DMD_FRM_CD      청구형태코드
# 3                FOM_CD        서식코드
# 4                    no     수진자고유번호
# 5                   AGG         연령군
# 6         SelectionProb        추출확률
# 7        SamplingWeight       샘플가중치
# 8               PAT_AGE       수진자연령
# 9             SEX_TP_CD      성별구분코드
# 10          INSUP_TP_CD       보험자코드
# 11             MSICK_CD       주상병코드
# 12             SSICK_CD       부상병코드
# 13           RECU_FR_DD      요양개시일자
# 14           RECU_TO_DD      요양만료일자
# 15         DGRSLT_TP_CD    진료결과구분코드
# 16            DGSBJT_CD      진료과목코드
# 17           DMD_DRG_NO     청구DRG번호
# 18          FST_IPAT_DD      최초입원일자
# 19  IPAT_ARIV_PTH_TP_CD  입원도착경로구분코드
# 20           OINJ_TP_CD      공상구분코드
# 21           RECU_DDCNT        요양일수
# 22            VST_DDCNT        내원일수
# 23     RVD_RPE_TAMT_AMT  심결요양급여비용총액
# 24     RVD_SLF_BRDN_AMT     심결본인부담금
# 25   RVD_INSUP_BRDN_AMT    심결보험자부담금
# 26              SOPR_YN        수술여부
# 27       PRCL_SYM_TP_CD    특정기호구분코드
# 28            MAIDCL_CD    의료급여종별코드
# 29         RADT_DIAG_YN     방사선진단여부
# 30         RADT_TRET_YN     방사선치료여부
# 31                  yno   요양기관 고유번호, '30':                        변수명      표준한글컬럼명
# 0                      key     명세서 연결코드
# 1                    CZ_CD          항코드
# 2                  ITEM_CD          목코드
# 3                DIV_TY_CD       분류유형코드
# 4                   DIV_CD         분류코드
# 5            SP1_SP2_TP_CD      1_2구분코드
# 6                    UNPRC           단가
# 7             FQ1_MDCT_QTY        1회투약량
# 8             DY1_MDCT_QTY        1일투약량
# 9     DY1_INJC_QTY_EXEC_FQ    1일투여량실시횟수
# 10  TOT_INJC_DDCNT_EXEC_FQ  총투여일수또는실시횟수
# 11  TOT_USE_QTY_OR_EXEC_FQ   총사용량또는실시횟수
# 12                     AMT           금액
# 13            ADDC_ADT_AMT       가산적용금액
# 14                   LN_NO          줄번호
# 15               GNL_NM_CD        일반명코드}
# {'20':                     변수명     표준한글컬럼명
# 0                   key    명세서 연결코드
# 1             DMD_TP_CD      청구구분코드
# 2            DMD_FRM_CD      청구형태코드
# 3                FOM_CD        서식코드
# 4                    no     수진자고유번호
# 5                   AGG         연령군
# 6         SelectionProb        추출확률
# 7        SamplingWeight       샘플가중치
# 8               PAT_AGE       수진자연령
# 9             SEX_TP_CD      성별구분코드
# 10          INSUP_TP_CD       보험자코드
# 11             MSICK_CD       주상병코드
# 12             SSICK_CD       부상병코드
# 13           RECU_FR_DD      요양개시일자
# 14           RECU_TO_DD      요양만료일자
# 15         DGRSLT_TP_CD    진료결과구분코드
# 16            DGSBJT_CD      진료과목코드
# 17           DMD_DRG_NO     청구DRG번호
# 18          FST_IPAT_DD      최초입원일자
# 19  IPAT_ARIV_PTH_TP_CD  입원도착경로구분코드
# 20           OINJ_TP_CD      공상구분코드
# 21           RECU_DDCNT        요양일수
# 22            VST_DDCNT        내원일수
# 23     RVD_RPE_TAMT_AMT  심결요양급여비용총액
# 24     RVD_SLF_BRDN_AMT     심결본인부담금
# 25   RVD_INSUP_BRDN_AMT    심결보험자부담금
# 26              SOPR_YN        수술여부
# 27       PRCL_SYM_TP_CD    특정기호구분코드
# 28            MAIDCL_CD    의료급여종별코드
# 29         RADT_DIAG_YN     방사선진단여부
# 30         RADT_TRET_YN     방사선치료여부
# 31                  yno   요양기관 고유번호, '30':                        변수명      표준한글컬럼명
# 0                      key     명세서 연결코드
# 1                    CZ_CD          항코드
# 2                  ITEM_CD          목코드
# 3                DIV_TY_CD       분류유형코드
# 4                   DIV_CD         분류코드
# 5            SP1_SP2_TP_CD      1_2구분코드
# 6                    UNPRC           단가
# 7             FQ1_MDCT_QTY        1회투약량
# 8             DY1_MDCT_QTY        1일투약량
# 9     DY1_INJC_QTY_EXEC_FQ    1일투여량실시횟수
# 10  TOT_INJC_DDCNT_EXEC_FQ  총투여일수또는실시횟수
# 11  TOT_USE_QTY_OR_EXEC_FQ   총사용량또는실시횟수
# 12                     AMT           금액
# 13            ADDC_ADT_AMT       가산적용금액
# 14                   LN_NO          줄번호
# 15               GNL_NM_CD        일반명코드, '40':               변수명   표준한글컬럼명
# 0             key  명세서 연결코드
# 1        SICK_SNO    상병일련번호
# 2  SICK_DGSBJT_CD  상병진료과목코드
# 3    DMD_SICK_SYM    청구상병기호
# 4   DMD_DGSBJT_CD  청구진료과목코드}
# {'20':                     변수명     표준한글컬럼명
# 0                   key    명세서 연결코드
# 1             DMD_TP_CD      청구구분코드
# 2            DMD_FRM_CD      청구형태코드
# 3                FOM_CD        서식코드
# 4                    no     수진자고유번호
# 5                   AGG         연령군
# 6         SelectionProb        추출확률
# 7        SamplingWeight       샘플가중치
# 8               PAT_AGE       수진자연령
# 9             SEX_TP_CD      성별구분코드
# 10          INSUP_TP_CD       보험자코드
# 11             MSICK_CD       주상병코드
# 12             SSICK_CD       부상병코드
# 13           RECU_FR_DD      요양개시일자
# 14           RECU_TO_DD      요양만료일자
# 15         DGRSLT_TP_CD    진료결과구분코드
# 16            DGSBJT_CD      진료과목코드
# 17           DMD_DRG_NO     청구DRG번호
# 18          FST_IPAT_DD      최초입원일자
# 19  IPAT_ARIV_PTH_TP_CD  입원도착경로구분코드
# 20           OINJ_TP_CD      공상구분코드
# 21           RECU_DDCNT        요양일수
# 22            VST_DDCNT        내원일수
# 23     RVD_RPE_TAMT_AMT  심결요양급여비용총액
# 24     RVD_SLF_BRDN_AMT     심결본인부담금
# 25   RVD_INSUP_BRDN_AMT    심결보험자부담금
# 26              SOPR_YN        수술여부
# 27       PRCL_SYM_TP_CD    특정기호구분코드
# 28            MAIDCL_CD    의료급여종별코드
# 29         RADT_DIAG_YN     방사선진단여부
# 30         RADT_TRET_YN     방사선치료여부
# 31                  yno   요양기관 고유번호, '30':                        변수명      표준한글컬럼명
# 0                      key     명세서 연결코드
# 1                    CZ_CD          항코드
# 2                  ITEM_CD          목코드
# 3                DIV_TY_CD       분류유형코드
# 4                   DIV_CD         분류코드
# 5            SP1_SP2_TP_CD      1_2구분코드
# 6                    UNPRC           단가
# 7             FQ1_MDCT_QTY        1회투약량
# 8             DY1_MDCT_QTY        1일투약량
# 9     DY1_INJC_QTY_EXEC_FQ    1일투여량실시횟수
# 10  TOT_INJC_DDCNT_EXEC_FQ  총투여일수또는실시횟수
# 11  TOT_USE_QTY_OR_EXEC_FQ   총사용량또는실시횟수
# 12                     AMT           금액
# 13            ADDC_ADT_AMT       가산적용금액
# 14                   LN_NO          줄번호
# 15               GNL_NM_CD        일반명코드, '40':               변수명   표준한글컬럼명
# 0             key  명세서 연결코드
# 1        SICK_SNO    상병일련번호
# 2  SICK_DGSBJT_CD  상병진료과목코드
# 3    DMD_SICK_SYM    청구상병기호
# 4   DMD_DGSBJT_CD  청구진료과목코드, '53':                        변수명      표준한글컬럼명
# 0                      key     명세서 연결코드
# 1                    LN_NO          줄번호
# 2           PRSCP_GRANT_NO      처방전교부번호
# 3                DIV_TY_CD       분류유형코드
# 4                    UNPRC           단가
# 5             FQ1_MDCT_QTY        1회투약량
# 6             DY1_MDCT_QTY        1일투약량
# 7   TOT_INJC_DDCNT_EXEC_FQ  총투여일수또는실시횟수
# 8   TOT_USE_QTY_OR_EXEC_FQ   총사용량또는실시횟수
# 9                      AMT           금액
# 10               GNL_NM_CD        일반명코드}

# %%
df_dict['20']
# Out:
#        key   no  DMD_FRM_CD  DMD_TP_CD  FOM_CD  AGG  SelectionProb  \
# 0        1  169           3          0       3   13       0.030001
# 1        2  183           3          0       8   15       0.030000
# 2        3   23           3          0       3    3       0.030000
# 3        4   96           3          0       5   14       0.030000
# 4        5   28           3          0       3    4       0.030001
# ...    ...  ...         ...        ...     ...  ...            ...
# 5626  5627  178           3          0       5    2       0.030000
# 5627  5628  295           3          0       3    4       0.030001
# 5628  5629  246           3          0       3    1       0.030000
# 5629  5630  253           3          0       3   10       0.030000
# 5630  5631  250           3          0       3   13       0.030001
#
#       SamplingWeight  PAT_AGE  SEX_TP_CD  ...  VST_DDCNT RVD_RPE_TAMT_AMT  \
# 0          33.332599     62.0          1  ...          1             9430
# 1          33.332882     74.0          2  ...          1             4380
# 2          33.332920     14.0          1  ...          1             3310
# 3          33.333002     68.0          1  ...          1            26660
# 4          33.332721     19.0          1  ...          1             9430
# ...              ...      ...        ...  ...        ...              ...
# 5626       33.332844      9.0          2  ...          1            13310
# 5627       33.332721     20.0          1  ...          1            71310
# 5628       33.333050      4.0          1  ...          1            13820
# 5629       33.332913     47.0          2  ...          1             9430
# 5630       33.332599     65.0          1  ...          1            14100
#
#      RVD_SLF_BRDN_AMT  RVD_INSUP_BRDN_AMT  SOPR_YN  PRCL_SYM_TP_CD  MAIDCL_CD  \
# 0                2800                6630        0               $          $
# 1                 500                3880        0               $          $
# 2                1300                2010        0               $          $
# 3                7900               18760        0               $          $
# 4                2800                6630        0               $          $
# ...               ...                 ...      ...             ...        ...
# 5626             3900                9410        0               $          $
# 5627             3500               67810        0            V193          $
# 5628             2900               10920        0               $          $
# 5629             2800                6630        0               $          $
# 5630             5600                8500        0               $          $
#
#      RADT_DIAG_YN  RADT_TRET_YN    yno
# 0               $             $  30796
# 1               $             $   9795
# 2               $             $  34835
# 3               $             $  35538
# 4               $             $   4665
# ...           ...           ...    ...
# 5626            $             $  21762
# 5627            $             $  45362
# 5628            $             $  12083
# 5629            $             $  21067
# 5630            $             $  33688
#
# [5631 rows x 32 columns]
