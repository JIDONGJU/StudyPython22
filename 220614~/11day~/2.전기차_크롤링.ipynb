# %% [markdown]
# ## 전기차 제조사별 가격, 연료, 주행, 연비, 출력 크롤링

# %% [markdown]
# ### 네이버 크롤링

# %%
from bs4 import BeautifulSoup as bs
from selenium import webdriver
import time
import pandas as pd

# %%
# 크롬드라이버로 네이버 열기
driver = webdriver.Chrome("C:/ChromeDriver_exe/chromedriver.exe")
driver.get('https://www.naver.com')
time.sleep(2)

# 검색어칸 클릭
driver.find_element_by_id('query').click()
# 검색 단어 입력하기
query_txt = input('크롤링할 키워드는 무엇입니까?')
# ??
element = driver.find_element_by_id('query')
# 검색어칸에 검색어 넣기
element.send_keys(query_txt)
# 검색하기 클릭
driver.find_element_by_class_name('ico_search_submit').click()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_14028\3575663236.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:/ChromeDriver_exe/chromedriver.exe")
# C:\Users\admin\AppData\Local\Temp\ipykernel_14028\3575663236.py:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('query').click()
# C:\Users\admin\AppData\Local\Temp\ipykernel_14028\3575663236.py:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   element = driver.find_element_by_id('query')
# C:\Users\admin\AppData\Local\Temp\ipykernel_14028\3575663236.py:15: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   driver.find_element_by_class_name('ico_search_submit').click()

# %% [markdown]
# - onclick 실행 방법
#     - 아래 실행문에 selector 붙여넣기

# %%
# 유종 선택
a = driver.find_element_by_css_selector("#main_pack > div.sc_new.cs_common_module.case_list.color_1._list_car > div.cm_content_wrap > div > div > div.cm_filter_tap > div.filter_tap_area._filter_tap > div > div > ul > li:nth-child(35) > div > a")
a.send_keys("\n")
time.sleep(2)

# 전기 선택
a = driver.find_element_by_css_selector("#main_pack > div.sc_new.cs_common_module.case_list.color_1._list_car > div.cm_content_wrap > div > div > div.cm_filter_tap > div.filter_option > div > div > div.panel_content > div.option_info._filter._scroller > div:nth-child(13) > div > ul > li:nth-child(6) > a")
a.send_keys("\n")
time.sleep(2)

# 적용하기
a = driver.find_element_by_css_selector("#main_pack > div.sc_new.cs_common_module.case_list.color_1._list_car > div.cm_content_wrap > div > div > div.cm_filter_tap > div.filter_option > div > div > div.panel_content > div.button_entire.height_50 > a")
a.send_keys("\n")
time.sleep(2)

# 필터링 된 차량 선택하기
a = driver.find_element_by_css_selector("#main_pack > div.sc_new.cs_common_module.case_list.color_1._list_car > div.cm_content_wrap > div > div > div._list._panel_wrapper > div:nth-child(1) > div > div:nth-child(1) > div.info_area > strong > a")
a.send_keys("\n")
time.sleep(2)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_14028\3133506974.py:2: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   a = driver.find_element_by_css_selector("#main_pack > div.sc_new.cs_common_module.case_list.color_1._list_car > div.cm_content_wrap > div > div > div.cm_filter_tap > div.filter_tap_area._filter_tap > div > div > ul > li:nth-child(35) > div > a")
# C:\Users\admin\AppData\Local\Temp\ipykernel_14028\3133506974.py:7: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   a = driver.find_element_by_css_selector("#main_pack > div.sc_new.cs_common_module.case_list.color_1._list_car > div.cm_content_wrap > div > div > div.cm_filter_tap > div.filter_option > div > div > div.panel_content > div.option_info._filter._scroller > div:nth-child(13) > div > ul > li:nth-child(6) > a")
# C:\Users\admin\AppData\Local\Temp\ipykernel_14028\3133506974.py:12: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   a = driver.find_element_by_css_selector("#main_pack > div.sc_new.cs_common_module.case_list.color_1._list_car > div.cm_content_wrap > div > div > div.cm_filter_tap > div.filter_option > div > div > div.panel_content > div.button_entire.height_50 > a")
# C:\Users\admin\AppData\Local\Temp\ipykernel_14028\3133506974.py:17: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   a = driver.find_element_by_css_selector("#main_pack > div.sc_new.cs_common_module.case_list.color_1._list_car > div.cm_content_wrap > div > div > div._list._panel_wrapper > div:nth-child(1) > div > div:nth-child(1) > div.info_area > strong > a")

# %% [markdown]
# - 차 정보 가져오기 (가격, 연료, 연비, 출력, 엔진)

# %%
# 페이지 소스 저장
html = driver.page_source
html

# ??
soup = bs(html, "html.parser")
soup

# 차량 기본정보 가져오기
title_1 = []
contents_1 = []
car_name_1 = []

car_name = soup.select("#main_pack > div.sc_new.cs_common_module.case_normal.color_23._cs_car_single._cs_bike_single > div:nth-child(3) > div > div.title_area.type_keep._title_area > h2 > span > strong")
car_name_1.append(car_name[0].text)

for i in range(0, 5, 1):
    title = soup.select("div.info_group > dt")
    title_1.append(title[i].text)
    contents = soup.select("div.info_group > dd")
    contents_1.append(contents[i].text.split(' ')[0])

print(car_name_1)
print(title_1)
print(contents_1)
# Out:
# ['현대 그랜저 하이브리드']
# ['가격', '연료 ', '연비 ', '출력 ', '엔진 ']
# ['3,787~4,606만원', '전기,', '복합', '200hp/159hp/38kW', 'I4']

# %%
# 뒤로 가기
driver.back()

# %%
# 두번째 차량 선택하기
# 위에 필터링 된 차량 선택하기에서 css패턴을 파악해서 반복문?

a = driver.find_element_by_css_selector("#main_pack > div.sc_new.cs_common_module.case_list.color_1._list_car > div.cm_content_wrap > div > div > div._list._panel_wrapper > div:nth-child(1) > div > div:nth-child(1) > div.info_area > strong > a")
a.send_keys("\n")
time.sleep(2)

# 필터링된 차량이 모두 보이는 페이지에서 href값들을 추출해서 반복해서 실행시켜야 하나?
# 기아 테슬라 등 모두 그렇게 수작업이 필요한가?

# %% [markdown]
# ### kepco plug 크롤링

# %%
# 크롬드라이버로 네이버 열기
driver = webdriver.Chrome("C:/ChromeDriver_exe/chromedriver.exe")
driver.get('https://evc.kepco.co.kr:4445/service/service03.do')
time.sleep(2)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_14028\877793532.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:/ChromeDriver_exe/chromedriver.exe")

# %%
# 페이지 소스 저장
html = driver.page_source
html

# ??
soup = bs(html, "html.parser")
soup
# Out:
# <html lang="ko"><head>
# <meta content="width=1300,user-scalable=yes" name="viewport"/>
# <meta content="07474af2f0cdef6f8431dc6900ddfe6e4e60d851" name="naver-site-verification"/>
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <title>한전 한국전력 전기차충전서비스(KEPCO PLUG, 켑코플러그)</title>
# <link href="/publish/com/css/style.css?version=20220624" rel="stylesheet" type="text/css"/>
# <link href="/publish/com/css/jquery-ui-1.10.3.custom.css" rel="stylesheet" type="text/css"/>
# <script src="/publish/com/js/jquery-1.9.1.min.js" type="text/javascript"></script>
# <script src="/publish/com/js/common.js" type="text/javascript"></script>
# <script src="/publish/com/js/jquery-ui-1.10.3.custom.js" type="text/javascript"></script>
# <script src="/publish/com/js/jquery.slides.min.js" type="text/javascript"></script>
# <script src="/resource/js/cm.validate.js" type="text/javascript"></script>
# </head>
# <body><div class="loading" id="evcDimmedLayer"></div>
# <div id="evcUploadLayer" style="display: none;">
# <div id="evcUploadProcess">
# <div class="uploaded_content c">
# <div class="file_load"><strong>파일업로드 중입니다.</strong></div>
# <div><img src="/publish/com/admin/images/file_road.gif"/></div>
# <p class="short_txt">잠시만 기다려주세요.</p>
# </div>
# </div>
# </div>
# <!-- s:modalpopup -->
# <div class="modal" id="g_modal">
# <p class="modal_content">
# </p><div id="pop_area"></div>
# <p></p>
# </div>
# <div id="skipnavi">
# <!-- 	<a href="#mapContainer">▶본문 바로가기</a> -->
# <!-- 	<a href="#gnbarea">▶주메뉴 바로가기</a> -->
# </div>
# <!-- wrapper -->
# <div id="wrapper">
# <div class="subBg" style="display: none;"></div>
# <!-- wrapBody -->
# <div id="wrapBody">
# <!-- TOP AREA s -->
# <script type="text/javascript">
# $(document).ready(function(){
# 	$("#btn_submit1").bind("click", function(){
#
# 		if($('#col2 option:selected').val()==""){
# 			alert("분류를 선택하세요.");
# 			return false;
# 		}
#
# 		var ctt = $("#ctt1").val();
#
# 		if(ctt == ""){
# 			alert("내용을 입력해주세요.");
# 			$("#ctt1").focus();
# 			return false;
# 		}
#
# 		board.submit();
# 		return false;
# 	});
#
# 	var process = "N";
# 	var board = {
# 		submit : function() {
# 			if(process == "Y"){
# 				alert("처리중입니다. 잠시만 기다려주세요."); return false;
# 			}
#
# 			opinionfrm.action="/main/insertProc.do";
# 			opinionfrm.target="opinionfrm2";
# 			opinionfrm.submit();
# 			$("#ctt1").val("");
# 		}
# 	  };
#
# function tempPcCompetition0819(){
# 	var date =new Date();
# 	var dd = date.getDate();
# 	var mm = date.getMonth()+1;
# 	var yyyy = date.getFullYear();
# 	var validd =19;
# 	var validd2 =30;
# 	var valmm = 8 ;
# 	var valyyyy = 2019;
# 	if((dd>=validd&&dd<=validd2)&&mm ==valmm&&yyyy==valyyyy){
# 		$("#tempPcCompetition0819").show();
# 	}
# }
# tempPcCompetition0819();
#
# });
#
# $(document).ready(function(){
# 	$(".gnb").on("mouseenter focusin",function(){
#
# 		if($(".subWrap").is(":hidden")){
# 			$(".subWrap").slideDown();
# 			$(".subBg").slideDown();
# 		}else{
# 			$(".subWrap").show();
# 			$(".subBg").show();
# 		}
#
# 		$(".gnb > li").on("mouseenter focusin",function(){
# 			$(".gnb > li > a").removeClass("current");
# 			$(this).children().addClass("current");
# 		});
#
# 	});
#
# 	$(".gnb").on("mouseleave blur",function(){
# 		$(".subWrap").slideUp();
# 		$(".subBg").slideUp();
# 	});
#
# 	$(".gnb > li").on("mouseleave blur",function(){
# 		$(this).children().removeClass("current");
# 	});
#
# 	$('*:not(".gnb *")').focus(function(){
# 		$(".subWrap").slideUp();
# 		$(".gnb > li > a").removeClass("current");
# 		$(".subBg").slideUp();
# 	});
#
# });
#
#
# function opinionOpen(){
# 	$("#opinionDiv").css("display","");
# }
#
# function opinioncolse(){
# 	$("#ctt").val("");
# 	$("#col2").val("");
# 	$("#opinionDiv").css("display","none");
# }
#
# function qnago(){
# 	location.href='/notice/list.do?boardCd=Q01';
# 	$("#opinionDiv").css("display","none");
# }
#
# function testLogin() {
#
# 	var memberId = $("#testuser").val();
# 	var memberPwd = $("#testuser").val();
#
# 	process = "Y";
# 	$.ajax({
# 		method: "POST",
# 	    url: "/cmmn/forntLoginTest.do",
# 	    data: {
# 	    	memberId : memberId,
# 	    	memberPwd : memberPwd
# 	    },
# 	    contentType: "application/x-www-form-urlencoded; charset=utf-8",
# 	    dataType: "json",
# 	    success: function(data) {
# 	    	if(data.resultType == "Y"){
#
# 	    		if(data.message != null && data.message != ""){
# 	    			alert(data.message);
# 	    		}
#
# 	    		document.location.href = "/main.do";
#
#
# 	    	}else if(data.resultType == "P"){
# 	    		process = "N";
# 	    		$("#searchDispYn").val("CHANGEPW");
# 	    		$("#dispay_view1").css("display", "");
# 	    		$("#footerBG").css("display", "");
# 	    	}else if(data.resultType == "S"){
# 	    		process = "N";
# 	    		$("#searchDispYn").val("CHANGEPW");
# 	    		$("#dispay_view2").css("display", "");
# 	    		$("#footerBG").css("display", "");
# 	    	}
# 	    	else{
# 	    		process = "N";
# 	    		alert(data.message);
# 	    		$("#memberPwd").focus();
# 	    		window.location.reload();
# 	    	}
# 	    },
# 	    error: function(jqXHR, textStatus, errorThrown) {
# 	    	process = "N";
# 	    	window.location.reload();
# 	        alert("잠시후 다시 시도해주세요.");
#
# 	    }
# 	});
#
# }
#
# function submitEncryptedForm(userId,password){
# 	var rsaPublicKeyModulus = document.getElementById("rsaPublicKeyModulus").value;
# 	var rsaPublicKeyExponent = document.getElementById("rsaPublicKeyExponent").value;
#
# 	var rsa = new RSAKey();
# 	rsa.setPublic(rsaPublicKeyModulus,rsaPublicKeyExponent);
#
# 	var SecuredUserId = rsa.encrypt(userId);
# 	var SecuredPassword = rsa.encrypt(password);
#
# 	var securedLoginForm = document.getElementById("defaultFrm");
# 	securedLoginForm.securedUserId.value = SecuredUserId;
# 	securedLoginForm.securedPassword.value = SecuredPassword;
#
# }
#
# </script>
# <!-- header -->
# <div id="header">
# <div class="inner_header">
# <!-- s:190308 -->
# <h1 class="logo"><a href="/main.do"><img alt="KEPCO 전기차 충전서비스" class="logo" src="/publish/images/common/plugLogo.png"/></a></h1>
# <!-- s:190308 -->
# <!-- topMenu -->
# <div class="topMenu">
# <ul class="clear">
# <li><a href="/main.do"><img alt="" src="/publish/images/common/icon_util01.png"/><span>HOME</span></a></li>
# <li><a href="/corp/main.do"><span>법인고객</span></a></li>
# <li><a href="/cmmn/frontLogin.do"><img alt="" src="/publish/images/common/icon_util02.png"/><span>로그인</span></a></li>
# <li><a href="#" onclick="opinionOpen()"><img alt="" src="/publish/images/common/icon_util06.png"/><span>개선의견</span></a></li>
# <li><a href="/main/termsView.do"><img alt="" src="/publish/images/common/icon_util08.png"/><span>이용약관</span></a></li>
# <li><a href="/sitemap.do"><img alt="" src="/publish/images/common/icon_util03.png"/><span>사이트맵</span></a></li>
# </ul>
# </div>
# <!--// topMenu -->
# <!-- gnb 시작 -->
# <h2 class="hidden-obj">주메뉴</h2>
# <div class="privateClientMenu" id="gnbarea">
# <ul class="gnb clear">
# <li><a href="/service/service01.do">서비스 안내</a>
# <div class="subWrap sub01" style="display: none;">
# <ul>
# <li><a href="/service/service01.do">Web/App</a></li>
# <li><a href="/service/service02.do">공용 충전소</a></li>
# <li><a href="/service/service05.do">아파트용 충전소</a></li>
# <!-- 191024 --><li><a href="/service/service11.do">충전요금</a></li>
# <li><a href="/service/service06.do">전기차 충전방식</a></li>
# <li><a href="/service/service10.do">이용방법 동영상</a></li>
# </ul>
# </div>
# </li>
# <li><a href="/map/map.do">충전소 조회</a>
# <div class="subWrap sub02" style="display: none;">
# <ul>
# <li><a href="/map/map.do">충전소 조회</a></li>
# </ul>
# </div>
# </li>
# <li><a href="/service/service03.do">통계정보</a>
# <div class="subWrap sub03" style="display: none;">
# <ul>
# <li><a href="/service/service03.do">전기차 현황</a></li>
# <li><a href="/service/service04.do">충전기 현황</a></li>
# </ul>
# </div>
# </li>
# <li><a href="/notice/list.do?boardCd=N01">고객지원</a>
# <div class="subWrap sub04" style="display: none;">
# <ul>
# <li><a href="/notice/list.do?boardCd=N01">공지사항</a></li>
# <li><a href="/notice/list.do?boardCd=F01">FAQ</a></li>
# <!-- <li><a href="/notice/list.do?boardCd=Q01">Q&amp;A</a></li> -->
# <li><a href="/notice/list.do?boardCd=D01">자료실</a></li>
# </ul>
# </div>
# </li>
# <li id="tempPcCompetition0819" style="display:none"><a href="http://home.kepco.co.kr/kepco/CT2/contest/main/contestMain.do">APT 공모</a></li>
# <li><a href="/mypage/myimp.do" onclick='if( "" == "") { alert("로그인후 이용가능합니다.");document.location.href="/cmmn/frontLogin.do" ;}'>마이페이지</a>
# <div class="subWrap sub05" style="display: none;">
# <ul>
# <li><a href="/mypage/myimp.do" onclick='if( "" == "") { alert("로그인후 이용가능합니다.");}'>내정보/간편결제</a></li>
# <li><a href="/mypage/chargebreakdown.do" onclick='if( "" == "") { alert("로그인후 이용가능합니다.");}'>충전내역</a></li>
# <li><a href="/mypage/myMinapList.do" onclick='if( "" == "") { alert("로그인후 이용가능합니다.");}'>미납내역</a></li>
# <li><a href="/mypage/bookmark.do" onclick='if( "" == "") { alert("로그인후 이용가능합니다.");}'>즐겨찾기</a></li>
# <li><a href="/notice/list.do?boardCd=Q01" onclick='if( "" == "") { alert("로그인후 이용가능합니다.");}'>Q&amp;A</a></li>
# <li><a href="/mypage/gpointInfo.do" onclick='if( "" == "") { alert("로그인후 이용가능합니다.");}'>그린포인트이력</a></li>
# <li><a href="/mypage/csReviewList.do" onclick='if( "" == "") { alert("로그인후 이용가능합니다.");}'>이용후기</a></li>
# <li><a href="/mypage/memFailCkList.do" onclick='if( "" == "") { alert("로그인후 이용가능합니다.");}'>고장신고내역</a></li>
# </ul>
# </div>
# </li>
# <!-- 					<li><a href="/cloud/cloudService01.do">클라우드서비스</a> -->
# <!-- 						<div class="subWrap sub06"> -->
# <!-- 							<ul> -->
# <!-- 								<li><a href="/cloud/cloudService01.do">서비스개요</a></li> -->
# <!-- 								<li><a href="/cloud/cloudService02.do">이용절차</a></li> -->
# <!-- 								<li><a href="/cloud/cloudService03.do">상품구성</a></li> -->
# <!-- 								<li><a href="/cloud/cloudService04.do">요금제</a></li> -->
# <!-- 								<li><a href="/cloud/cloudAplForm.do">이용신청</a></li> -->
# <!-- 								<li><a href="/cloud/cloudService05.do">이용약관</a></li>								 -->
# <!-- 							</ul> -->
# <!-- 						</div> -->
# <!-- 					</li>	 -->
# <!-- <li><a href="/main/inovtInfo.do">혁신 아이디어 공모</a>
# 						<div class="subWrap sub07">
# 							<ul>
# 								<li><a href="/main/inovtInfo.do">공모개요</a></li>
# 								<li><a href="/main/inovtAgreeInfo.do">접수하기</a></li>
# 								<li><a href="/main/inovtAcptList.do">나의 접수 현황</a></li>
# 								<li><a href="/main/inovtResult.do">공모결과</a></li>
# 							</ul>
# 						</div>
# 					</li> -->
# </ul>
# </div>
# <!-- //gnb 끝 -->
# <p class="csCenter">고객센터 <strong class="num">1899-2100</strong></p>
# </div>
# </div> <!--//header-->
# <div id="opinionDiv" style="display: none; position:fixed; left:50%; top:150px; margin-left:-325px;z-index:99;">
# <div class="new_popup" style="width:650px;height:450px;">
# <div class="pop_header">
# <h1>개선의견 <a class="pop_close" href="#" onclick="opinioncolse()">닫기</a></h1>
# </div>
# <div class="pop_content">
# <form id="opinionfrm" method="post" name="opinionfrm">
# <input id="boardCd" name="boardCd" type="hidden" value="O01"/>
# <p class="s_tit">현 사이트의 문제점 또는 개선사항에 대한 고객님의 의견을 작성해주세요.</p>
# <p class="s_tit_txt">본 게시판은 회신을 제공하지 않습니다. <br/>문의사항, 민원신청, 불만사항 등은 고객지원서비스를 이용해 주시기 바랍니다. </p>
# <div class="mar_t10">
# <table class="board_view">
# <caption>개선사항 의견 제출</caption>
# <colgroup>
# <col style="width:15%"/>
# <col/>
# </colgroup>
# <tbody>
# <tr>
# <th class="bg" scope="row">분류</th>
# <td class="tit_l">
# <select id="col2" name="col2" title="분류 선택">
# <option selected="selected" value="">선택하세요</option>
# <option value="CO">콘텐츠</option>
# <option value="DI">디자인</option>
# <option value="US">사용성</option>
# <option value="ET">기타</option>
# </select>
# </td>
# </tr>
# <tr>
# <th class="bg" scope="row">내용</th>
# <td class="tit_l">
# <textarea class="txt_area" id="ctt1" name="ctt1" title="내용입력"></textarea>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="btn_area c mar_t20">
# <a class="btn_big02 green" href="#" id="btn_submit1">제출</a>
# <a class="btn_big02 white" href="#" onclick="opinioncolse()">취소</a>
# </div>
# </form>
# </div>
# </div>
# <iframe frameborder="0" height="0" id="opinionfrm2" name="opinionfrm2" stitle="업무 처리용 프레임" style="display:none;" width="0"></iframe>
# </div>
# <!--// header -->
# <!--// TOP AREA e -->
# <hr/>
# <!-- contents -->
# <script src="/publish/com/js/highcharts.js" type="text/javascript"></script>
# <script src="/publish/com/js/exporting.js" type="text/javascript"></script>
# <script type="text/javascript">
#
# var staticYear = new Array();
# var evStaticData = new Array();
# var cpStaticData = new Array();
# var chart1;
# var options1;
#
# $(document).ready(function(){
#
# 	evCar5YearStatic();
#
# });
#
# $(document).ready(function(){
#
#
#
# });
#
# function evCar5YearStatic() {
#  	$.ajax({
# 		method: "POST",
# 	        url: "/service/service03.json",
# 	    data: [],
# 	    contentType: "application/x-www-form-urlencoded; charset=utf-8",
# 	    dataType: "json",
# 	    crossDomain : true,
# 	    async:false,
# 	    success: function(data) {
# 			serviceEvStaticView(data.evStaticList);
# 			serviceCpStaticView(data.cpStaticList);
# 			serviceChart();
# 	    },
# 	    error: function(jqXHR, textStatus, errorThrown) {
# 	        alert("잠시후 다시 시도해주세요.");
# 	    }
# 	});
# }
#
# function serviceEvStaticView(result) {
#
# 	if(result.length>0){
#
# 		$.each(result, function(idx, vo){
# 			$("#yearHd"+(idx+1)).text(vo.static_year+"년");
# 			$("#yearDt"+(idx+1)).text(vo.totCnt_fmt);
#
# 			staticYear[idx] = vo.static_year+"년";
# 			evStaticData[idx] = Number(vo.totCnt);
#
# 			if(idx = (result.length-1)) {
# 				$("#static_ym").text("※ "+vo.static_ym+"월(출처 : 국토부)");
# 			}
#
# 		});
# 	}
#
# }
#
# function serviceCpStaticView(result) {
#
# 	if(result.length>0){
#
# 		$.each(result, function(idx, vo){
# 			cpStaticData[idx] = Number(vo.totCnt);
# 		});
# 	}
#
# }
#
# function serviceChart(){
#
# //   var top = chart.plotTop;
# //  	  var left = chart.plotLeft;
#
# //  	  var width = chart.plotSizeX;
# //  	  var height = chart.plotSizeY;
#
# //  	  var col = width/24 ;
#
# //  	  var max = chart.yAxis[0].max;
#
# //    var s = max*(1/3);
# //  	   var m = max*(2/3);
# //  	   var l = max;
#
# 	options1 = {
# 		chart: {
#         	renderTo: 'chart_container',
#         	renderer : {
#         		rect : {
#         			x : 10,
#         			y : 10,
#         			width: 10,
#         			height: 10,
#         			fill : 'rgba(254,164,0,1)'
#         		}
#         	}
#         },
# 		title: {
# 			text: false
# 		},
# 		navigation: {
# 		  buttonOptions: {
# 			y: -1000
# 		  }
# 		},
# 		credits: {
# 		  enabled: false
# 		},
# 		xAxis: {
# 			categories: [],
#             crosshair: true,
# 		},
# 		yAxis: [{
#             labels: false,
#             title: false,
#         }, { // Secondary yAxis
#             title: false,
#             labels: false,
#             opposite: true
#         }],
# 		tooltip: {
# 			shared: true
# 		},
# 		plotOptions: {
#             series: {
#                 borderWidth: 0,
#                 dataLabels: [{
#                     enabled: false,
#                     format: '{point.y:,.0f}'
#                 },
#                 {
#                     enabled: true,
#                     format: '{point.y:,.0f}'
#                 }]
#             }
#         },
# 		series: [{
#             name: '충전기현황',
#             type: 'column',
#             yAxis: 1,
#             data: [],
#             tooltip: {
#                 valueSuffix: '기'
#             }
#
#         }, {
#             name: '전기차현황',
#             type: 'line',
#             data: [],
#             tooltip: {
#                 valueSuffix: '대'
#             }
#         }]
# 	}
#
# //  var top = chart.plotTop;
# //  var left = chart.plotLeft;
#
# //  var width = chart.plotSizeX;
# //  var height = chart.plotSizeY;
#
# //  var col = width/24 ;
#
# //  var max = chart.yAxis[0].max;
#
# //var s = max*(1/3);
# //   var m = max*(2/3);
# //   var l = max;
#
# // 	chart.renderer.rect(left + ( col * 9 ), top+(height-height*(m/max)),  col, height*(m/max)).attr({
# // 		fill : 'rgba(254,164,0,0.1)'
# // 	}).add();
#
# 	//카테고리 값 셋팅
# 	console.log("staticYear::"+staticYear);
# 	console.log("evStaticData::"+evStaticData);
# 	options1.xAxis.categories = staticYear;
# 	console.log("xAxis::"+options1.xAxis.categories);
#
# 	//데이터 값 셋팅
# 	options1.series[0].data = cpStaticData;
# 	options1.series[1].data = evStaticData;
#
# 	chart1 = new Highcharts.Chart(options1); //차트생성
#
# }
# </script>
# <script type="text/javascript">
# 	$(document).ready(function(){
# 		//sub_tab
# 		$(".sub_tab > li > a").click(function(){
# 			$(this).parent().addClass("active").siblings().removeClass("active");
# 		});
# 	});
#
# 	function carListShow(num){
# 		carListHide();
# 		$("#carList"+num).show();
# 	}
# 	function carListHide(num){
# 		$("[id^='carList']").hide();
# 	}
# </script>
# <!-- wrap -->
# <div id="wrap">
# <!-- <div class="sub_visual ">
# 			<h3>통계정보</h3>
# 		</div> -->
# <h1>통계정보
# 			<span><a href="#">HOME</a> &gt; 통계정보 &gt; <strong>전기차 현황</strong></span>
# </h1>
# <div class="tab_wrap">
# <div class="tab01">
# <ul>
# <li class="active"><a href="/service/service03.do">전기차 현황</a></li>
# <li><a href="/service/service04.do">충전기 현황</a></li>
# </ul>
# </div>
# </div>
# <!-- //tab_wrap -->
# <!-- contents -->
# <div class="sub_contents" id="contents">
# <div class="in_content">
# <h4 class="h4_title">국내 전기자동차 소개</h4>
# <div class="sub_tab_wrap2">
# <ul class="sub_tab col10">
# <li class="active"><a href="#carList01" onclick="carListShow(1);return false;">기아자동차</a></li>
# <li><a href="#carList02" onclick="carListShow(2);return false;">현대자동차</a></li>
# <li><a href="#carList03" onclick="carListShow(3);return false;">르노 삼성</a></li>
# <li><a href="#carList04" onclick="carListShow(4);return false;">BMW</a></li>
# <li><a href="#carList05" onclick="carListShow(5);return false;">쉐보레</a></li>
# <li><a href="#carList06" onclick="carListShow(6);return false;">닛산</a></li>
# <li><a href="#carList07" onclick="carListShow(7);return false;">Tesla</a></li>
# <li><a href="#carList08" onclick="carListShow(8);return false;">쌍용</a></li>
# <li><a href="#carList09" onclick="carListShow(9);return false;">벤츠</a></li>
# <li><a href="#carList10" onclick="carListShow(10);return false;">한불모터스</a></li>
# <!-- 						<li><a href="#carList10" onclick="carListShow(10);return false;">한불모터스</a></li> -->
# <!-- 						<li><a href="#carList10" onclick="carListShow(10);return false;">한불모터스</a></li> -->
# </ul>
# </div>
# <!-- //sub_tab_wrap -->
# <div id="carList1">
# <ul class="car_list clear">
# <li class="first">
# <div class="car_img">
# <a href="https://www.kia.com/kr/vehicles/soulbooster-ev/features.html" rel="noopener noreferrer" target="_blank" title="기아자동차 홈페이지 바로가기(새창열림)"><img alt="기아자동차" src="/publish/images/sub/car_ev6.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>EV6</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> DC콤보</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 483Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온폴리머</li>
# <li><strong>배터리 용량 :</strong> 77.5Kwh</li>
# <li><strong>최고속도 :</strong> 185km/h</li>
# </ul>
# </div>
# </li>
# <li>
# <div class="car_img">
# <a href="http://www.kia.com/kr/vehicles/niro-ev/features.html" rel="noopener noreferrer" target="_blank" title="기아자동차 홈페이지 바로가기(새창열림)"><img alt="기아자동차" src="/publish/images/sub/car13.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>니로EV</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> DC콤보</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 385Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온폴리머</li>
# <li><strong>배터리 용량 :</strong> 64Kwh</li>
# <li><strong>최고속도 :</strong> 160km/h</li>
# </ul>
# </div>
# </li>
# <li class="first">
# <div class="car_img">
# <a href="https://www.kia.com/kr/vehicles/soulbooster-ev/features.html" rel="noopener noreferrer" target="_blank" title="기아자동차 홈페이지 바로가기(새창열림)"><img alt="기아자동차" src="/publish/images/sub/car14.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>쏘울 Booster</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> DC콤보</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 391Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온폴리머</li>
# <li><strong>배터리 용량 :</strong> 64Kwh</li>
# <li><strong>최고속도 :</strong> 155km/h</li>
# </ul>
# </div>
# </li>
# <li>
# <div class="car_img">
# <a href="http://www.kia.com/kr/vehicles/niro-ev/features.html" rel="noopener noreferrer" target="_blank" title="기아자동차 홈페이지 바로가기(새창열림)"><img alt="기아자동차" src="/publish/images/sub/car_bongo3ev.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>봉고Ⅲ EV</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> DC콤보</li>
# <li><strong>승차인원 :</strong> 3인승</li>
# <li><strong>1회충전 주행거리 :</strong> 385Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온폴리머</li>
# <li><strong>배터리 용량 :</strong> 64Kwh</li>
# <li><strong>최고속도 :</strong> 160km/h</li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# <!--// 기아자동차 -->
# <div id="carList2" style="display:none;">
# <ul class="car_list clear">
# <li class="first">
# <div class="car_img">
# <a href="http://www.hyundai.com/kr/showroom.do?carCd1=RD030&amp;WT.ac=direct_carkind_ioniqelectric" rel="noopener noreferrer" target="_blank" title="현대자동차 홈페이지 바로가기(새창열림)"><img alt="현대자동차" src="/publish/images/sub/car_ioniq5.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>아이오닉5 (IONIQ)</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> DC콤보</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 423Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온폴리머</li>
# <li><strong>배터리 용량 :</strong> 72.6Kwh</li>
# <li><strong>최고속도 :</strong> 185km/h</li>
# </ul>
# </div>
# </li>
# <li>
# <div class="car_img">
# <a href="https://www.hyundai.com/kr/ko/vehicles/kona-electric/highlights" rel="noopener noreferrer" target="_blank" title="현대자동차 홈페이지 바로가기(새창열림)"><img alt="현대자동차" src="/publish/images/sub/car_gv60.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>GV60</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> DC콤보</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 470Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온폴리머</li>
# <li><strong>배터리 용량 :</strong> 77.5Kwh</li>
# <li><strong>최고속도 :</strong> 185km/h</li>
# </ul>
# </div>
# </li>
# <li class="first">
# <div class="car_img">
# <a href="http://www.hyundai.com/kr/showroom.do?carCd1=RD030&amp;WT.ac=direct_carkind_ioniqelectric" rel="noopener noreferrer" target="_blank" title="현대자동차 홈페이지 바로가기(새창열림)"><img alt="현대자동차" src="/publish/images/sub/car_gv70.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>GV70</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> DC콤보</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 408Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온폴리머</li>
# <li><strong>배터리 용량 :</strong> 77.5Kwh</li>
# <li><strong>최고속도 :</strong> 235km/h</li>
# </ul>
# </div>
# </li>
# <li>
# <div class="car_img">
# <a href="https://www.hyundai.com/kr/ko/vehicles/kona-electric/highlights" rel="noopener noreferrer" target="_blank" title="현대자동차 홈페이지 바로가기(새창열림)"><img alt="현대자동차" src="/publish/images/sub/car_g80.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>G80</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> DC콤보</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 433Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온폴리머</li>
# <li><strong>배터리 용량 :</strong> 87.2Kwh</li>
# <li><strong>최고속도 :</strong> 225km/h</li>
# </ul>
# </div>
# </li>
# <li class="first">
# <div class="car_img">
# <a href="http://www.hyundai.com/kr/showroom.do?carCd1=RD030&amp;WT.ac=direct_carkind_ioniqelectric" rel="noopener noreferrer" target="_blank" title="현대자동차 홈페이지 바로가기(새창열림)"><img alt="현대자동차" src="/publish/images/sub/car05.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>아이오닉 (IONIQ)</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> DC콤보</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 271Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온폴리머</li>
# <li><strong>배터리 용량 :</strong> 38.3Kwh</li>
# <li><strong>최고속도 :</strong> 165km/h</li>
# </ul>
# </div>
# </li>
# <li>
# <div class="car_img">
# <a href="https://www.hyundai.com/kr/ko/vehicles/kona-electric/highlights" rel="noopener noreferrer" target="_blank" title="현대자동차 홈페이지 바로가기(새창열림)"><img alt="현대자동차" src="/publish/images/sub/car12.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>코나EV</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> DC콤보</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 482Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온폴리머</li>
# <li><strong>배터리 용량 :</strong> 58.86Kwh</li>
# <li><strong>최고속도 :</strong> 115km/h</li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# <!--// 현대자동차 -->
# <div id="carList3" style="display:none;">
# <ul class="car_list clear">
# <li class="first">
# <div class="car_img">
# <a href="http://www.renaultsamsungm.com/2016/vehicle/sm3ze.jsp" rel="noopener noreferrer" target="_blank" title="르노 삼성 홈페이지 바로가기(새창열림)"><img alt="르노 삼성" src="/publish/images/sub/car06.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>SM3 ZE</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> AC3상</li>
# <li><strong>승차인원 :</strong> 4인승</li>
# <li><strong>1회충전 주행거리 :</strong> 213Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온폴리머</li>
# <li><strong>배터리 용량 :</strong> 26.6Kwh</li>
# <li><strong>최고속도 :</strong> 135km/h</li>
# </ul>
# </div>
# </li>
# <li>
# <div class="car_img">
# <a href="http://www.renault.co.kr/vehicles/zoe.jsp" rel="noopener noreferrer" target="_blank" title="르노 삼성 홈페이지 바로가기(새창열림)"><img alt="르노삼성" src="/publish/images/sub/car_zoe.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>ZOE EV</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> DC콤보</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 309km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온</li>
# <li><strong>배터리 용량 :</strong> 54.5Kwh</li>
# <li><strong>최고속도 :</strong> 140km/h</li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# <!--// 르노삼성 -->
# <div id="carList4" style="display:none;">
# <ul class="car_list clear">
# <li class="first">
# <div class="car_img">
# <a href="http://www.bmw.co.kr/ko/all-models/bmw-i/i3/2013/at-a-glance.html" rel="noopener noreferrer" target="_blank" title="BMW 홈페이지 바로가기(새창열림)"><img alt="BMW" src="/publish/images/sub/car07.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>i3</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> DC콤보</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 248Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온</li>
# <li><strong>배터리 용량 :</strong> 37.9Kwh</li>
# <li><strong>최고속도 :</strong> 150km/h</li>
# </ul>
# </div>
# </li>
# <li>
# <div class="car_img">
# <a href="http://www.bmw.co.kr/ko/all-models/bmw-i/i3/2013/at-a-glance.html" rel="noopener noreferrer" target="_blank" title="BMW 홈페이지 바로가기(새창열림)"><img alt="BMW" src="/publish/images/sub/car_ix3.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>iX3</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> DC콤보</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 356.9km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온</li>
# <li><strong>배터리 용량 :</strong> 80.04Kwh</li>
# <li><strong>최고속도 :</strong> 180km/h</li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# <!--// BMW -->
# <div id="carList5" style="display:none;">
# <ul class="car_list clear">
# <li class="first">
# <div class="car_img">
# <a href="http://www.chevrolet.co.kr/ev/boltev-highlight.gm" rel="noopener noreferrer" target="_blank" title="쉐보레 홈페이지 바로가기(새창열림)"><img alt="쉐보레" src="/publish/images/sub/car11.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>볼트(BOLT EV)</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> DC콤보</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 383km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온</li>
# <li><strong>배터리 용량 :</strong> 60Kwh</li>
# <li><strong>최고속도 :</strong> 154km/h</li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# <!--// 쉐보레 -->
# <div id="carList6" style="display:none;">
# <ul class="car_list clear">
# <li class="first">
# <div class="car_img">
# <a href="http://www.nissan.co.kr/electronic/leaf.asp" rel="noopener noreferrer" target="_blank" title="닛산 홈페이지 바로가기(새창열림)"><img alt="닛산" src="/publish/images/sub/car03.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>리프 (LEAF)</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> 차데모</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 172Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온</li>
# <li><strong>배터리 용량 :</strong> 40Kwh</li>
# <li><strong>최고속도 :</strong> 140km/h</li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# <!--// 닛산 -->
# <div id="carList7" style="display:none;">
# <ul class="car_list clear">
# <li class="first">
# <div class="car_img">
# <a href="https://www.tesla.com/ko_KR/models" rel="noopener noreferrer" target="_blank" title="테슬라 홈페이지 바로가기(새창열림)"><img alt="테슬라" src="/publish/images/sub/car08.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>모델S</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> AC3상</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 378Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온</li>
# <li><strong>배터리 용량 :</strong> 90Kwh</li>
# <li><strong>최고속도 :</strong> 250km/h</li>
# </ul>
# </div>
# </li>
# <li>
# <div class="car_img">
# <a href="https://www.tesla.com/ko_KR/model3" rel="noopener noreferrer" target="_blank" title="테슬라 홈페이지 바로가기(새창열림)"><img alt="테슬라" src="/publish/images/sub/car15.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>모델3</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> 테슽라전용</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 527Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온</li>
# <li><strong>배터리 용량 :</strong>84.96Kwh</li>
# <li><strong>최고속도 :</strong> 233km/h</li>
# </ul>
# </div>
# </li>
# <li class="first">
# <div class="car_img">
# <a href="https://www.tesla.com/ko_KR/models" rel="noopener noreferrer" target="_blank" title="테슬라 홈페이지 바로가기(새창열림)"><img alt="테슬라" src="/publish/images/sub/car_modely.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>모델Y</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> 테슽라전용</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 511Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온</li>
# <li><strong>배터리 용량 :</strong>84.96Kwh</li>
# <li><strong>최고속도 :</strong> 217km/h</li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# <!--// 테슬라 -->
# <div id="carList8" style="display:none;">
# <ul class="car_list clear">
# <li class="first">
# <div class="car_img">
# <a href="https://www.smotor.com/kr/showroom/korandoemotion/index.html" rel="noopener noreferrer" target="_blank" title="쌍용자동차 홈페이지 바로가기(새창열림)"><img alt="쌍용자동차" src="/publish/images/sub/car_emotion.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>코란도 e-motion</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> DC콤보</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 307Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온</li>
# <li><strong>배터리 용량 :</strong>61.4Kwh</li>
# <li><strong>최고속도 :</strong> 163km/h</li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# <!--// 쌍용자동차 -->
# <div id="carList9" style="display:none;">
# <ul class="car_list clear">
# <li class="first">
# <div class="car_img">
# <a href="https://www.mercedes-benz.co.kr/passengercars/models.html?group=all&amp;subgroup=see-all&amp;view=BODYTYPE" rel="noopener noreferrer" target="_blank" title="벤츠 홈페이지 바로가기(새창열림)"><img alt="벤츠" src="/publish/images/sub/car_eqa250.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>EQA250</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> DC콤보</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 302.7Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온</li>
# <li><strong>배터리 용량 :</strong>61.4Kwh</li>
# <li><strong>최고속도 :</strong> 160km/h</li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# <!--// 벤츠 -->
# <div id="carList10" style="display:none;">
# <ul class="car_list clear">
# <li class="first">
# <div class="car_img">
# <a href="#" rel="noopener noreferrer" target="_blank" title="한불모터스 홈페이지 바로가기(새창열림)"><img alt="한불모터스" src="/publish/images/sub/car_etense.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>DS3 E-tense</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> DC콤보</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 237Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온</li>
# <li><strong>배터리 용량 :</strong>47.4Kwh</li>
# <li><strong>최고속도 :</strong> 150km/h</li>
# </ul>
# </div>
# </li>
# <li>
# <div class="car_img">
# <a href="#" rel="noopener noreferrer" target="_blank" title="한불모터스 홈페이지 바로가기(새창열림)"><img alt="한불모터스" src="/publish/images/sub/car_e2008.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>Peugeot e-2008</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> DC콤보</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 237Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온</li>
# <li><strong>배터리 용량 :</strong>47.4Kwh</li>
# <li><strong>최고속도 :</strong> 150km/h</li>
# </ul>
# </div>
# </li>
# <li class="first">
# <div class="car_img">
# <a href="#" rel="noopener noreferrer" target="_blank" title="한불모터스 홈페이지 바로가기(새창열림)"><img alt="한불모터스" src="/publish/images/sub/car_e208.png"/></a>
# </div>
# <div class="car_list_txt">
# <h6>Peugeot e-208</h6>
# <ul class="blue_dot02">
# <li><strong>충전방식 :</strong> DC콤보</li>
# <li><strong>승차인원 :</strong> 5인승</li>
# <li><strong>1회충전 주행거리 :</strong> 244Km</li>
# <li><strong>배터리 종류 :</strong> 리튬이온</li>
# <li><strong>배터리 용량 :</strong>47.4Kwh</li>
# <li><strong>최고속도 :</strong> 150km/h</li>
# </ul>
# </div>
# </li>
# <!-- e:190610 -->
# </ul>
# </div>
# <!--// 한불모터스 -->
# <div class="car_list">
# <div class="left_cont">
# <h5 class="h5_title">지역별 전기차 보급현황<span class="abs">※ 2022.01월(출처 : 국토부)</span></h5>
# <div class="totalMap">
# <dl><dt>서울특별시</dt><dd>41,140</dd></dl>
# <dl><dt>인천광역시</dt><dd>12,942</dd></dl>
# <dl><dt>경기도</dt><dd>40,239</dd></dl>
# <dl><dt>강원도</dt><dd>8,042</dd></dl>
# <dl><dt>충청북도</dt><dd>8,184</dd></dl>
# <dl><dt>세종특별<br/>자치시</dt><dd>1,879</dd></dl>
# <dl><dt>충청남도</dt><dd>10,015</dd></dl>
# <dl><dt>대전광역시</dt><dd>7,675</dd></dl>
# <dl><dt>전라북도</dt><dd>7,389</dd></dl>
# <dl><dt>전라남도</dt><dd>8,837</dd></dl>
# <dl><dt>광주광역시</dt><dd>5,204</dd></dl>
# <dl><dt>경상북도</dt><dd>11,269</dd></dl>
# <dl><dt>대구광역시</dt><dd>16,169</dd></dl>
# <dl><dt>경상남도</dt><dd>12,725</dd></dl>
# <dl><dt>울산광역시</dt><dd>3,180</dd></dl>
# <dl><dt>부산광역시</dt><dd>12,501</dd></dl>
# <dl><dt>제주특별<br/>자치도</dt><dd>25,580</dd></dl>
# </div>
# </div>
# <div class="right_cont">
# <h5 class="h5_title">연도별 전기차 보급현황 <span class="abs" id="static_ym">※ 2022.05월(출처 : 국토부)</span></h5>
# <table class="service_table03" id="service03_static">
# <caption>연도별 전기차 보급현황 (단위 : 개)</caption>
# <colgroup>
# <col style="width:14.2%"/>
# <col style="width:14.2%"/>
# <col style="width:14.2%"/>
# <col style="width:14.2%"/>
# <col style="width:14.2%"/>
# <col style="width:14.2%"/>
# <col style="width:14.2%"/>
# </colgroup>
# <thead>
# <tr>
# <th class="bg" scope="row">년도</th>
# <th class="center" id="yearHd1">2017년</th>
# <th class="center" id="yearHd2">2018년</th>
# <th class="center" id="yearHd3">2019년</th>
# <th class="center" id="yearHd4">2020년</th>
# <th class="center" id="yearHd5">2021년</th>
# <th class="center bg_blue02 white" id="yearHd6">2022년</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="bg" scope="row">전기차 수</th>
# <td class="center" id="yearDt1">      25,593</td>
# <td class="center" id="yearDt2">      55,758</td>
# <td class="center" id="yearDt3">     101,049</td>
# <td class="center" id="yearDt4">     134,962</td>
# <td class="center" id="yearDt5">     231,497</td>
# <td class="center bold600" id="yearDt6">     286,258</td>
# </tr>
# </tbody>
# </table>
# <div data-highcharts-chart="0" id="chart_container" style="min-width: 680px; height: 400px; margin: 0 auto"><div class="highcharts-container" id="highcharts-tqve345-0" style="position: relative; overflow: hidden; width: 690px; height: 400px; text-align: left; line-height: normal; z-index: 0; -webkit-tap-highlight-color: rgba(0, 0, 0, 0);"><svg class="highcharts-root" height="400" style='font-family:"Lucida Grande", "Lucida Sans Unicode", Arial, Helvetica, sans-serif;font-size:12px;' version="1.1" viewbox="0 0 690 400" width="690" xmlns="http://www.w3.org/2000/svg"><desc>Created with Highcharts 5.0.4</desc><defs><clippath id="highcharts-tqve345-1"><rect fill="none" height="309" width="670" x="0" y="0"></rect></clippath></defs><rect class="highcharts-background" fill="#ffffff" height="400" rx="0" ry="0" width="690" x="0" y="0"></rect><rect class="highcharts-plot-background" fill="none" height="309" width="670" x="10" y="10"></rect><g class="highcharts-grid highcharts-xaxis-grid"><path class="highcharts-grid-line" d="M 121.5 10 L 121.5 319" fill="none" opacity="1"></path><path class="highcharts-grid-line" d="M 232.5 10 L 232.5 319" fill="none" opacity="1"></path><path class="highcharts-grid-line" d="M 344.5 10 L 344.5 319" fill="none" opacity="1"></path><path class="highcharts-grid-line" d="M 456.5 10 L 456.5 319" fill="none" opacity="1"></path><path class="highcharts-grid-line" d="M 567.5 10 L 567.5 319" fill="none" opacity="1"></path><path class="highcharts-grid-line" d="M 679.5 10 L 679.5 319" fill="none" opacity="1"></path><path class="highcharts-grid-line" d="M 9.5 10 L 9.5 319" fill="none" opacity="1"></path></g><g class="highcharts-grid highcharts-yaxis-grid"><path class="highcharts-grid-line" d="M 10 319.5 L 680 319.5" fill="none" opacity="1" stroke="#e6e6e6" stroke-width="1"></path><path class="highcharts-grid-line" d="M 10 257.5 L 680 257.5" fill="none" opacity="1" stroke="#e6e6e6" stroke-width="1"></path><path class="highcharts-grid-line" d="M 10 195.5 L 680 195.5" fill="none" opacity="1" stroke="#e6e6e6" stroke-width="1"></path><path class="highcharts-grid-line" d="M 10 134.5 L 680 134.5" fill="none" opacity="1" stroke="#e6e6e6" stroke-width="1"></path><path class="highcharts-grid-line" d="M 10 72.5 L 680 72.5" fill="none" opacity="1" stroke="#e6e6e6" stroke-width="1"></path><path class="highcharts-grid-line" d="M 10 10.5 L 680 10.5" fill="none" opacity="1" stroke="#e6e6e6" stroke-width="1"></path></g><g class="highcharts-grid highcharts-yaxis-grid"><path class="highcharts-grid-line" d="M 10 319.5 L 680 319.5" fill="none" opacity="1" stroke="#e6e6e6" stroke-width="1"></path><path class="highcharts-grid-line" d="M 10 257.5 L 680 257.5" fill="none" opacity="1" stroke="#e6e6e6" stroke-width="1"></path><path class="highcharts-grid-line" d="M 10 195.5 L 680 195.5" fill="none" opacity="1" stroke="#e6e6e6" stroke-width="1"></path><path class="highcharts-grid-line" d="M 10 134.5 L 680 134.5" fill="none" opacity="1" stroke="#e6e6e6" stroke-width="1"></path><path class="highcharts-grid-line" d="M 10 72.5 L 680 72.5" fill="none" opacity="1" stroke="#e6e6e6" stroke-width="1"></path><path class="highcharts-grid-line" d="M 10 9.5 L 680 9.5" fill="none" opacity="1" stroke="#e6e6e6" stroke-width="1"></path></g><rect class="highcharts-plot-border" fill="none" height="309" width="670" x="10" y="10"></rect><g class="highcharts-axis highcharts-xaxis"><path class="highcharts-tick" d="M 121.5 319 L 121.5 329" fill="none" opacity="1" stroke="#ccd6eb" stroke-width="1"></path><path class="highcharts-tick" d="M 232.5 319 L 232.5 329" fill="none" opacity="1" stroke="#ccd6eb" stroke-width="1"></path><path class="highcharts-tick" d="M 344.5 319 L 344.5 329" fill="none" opacity="1" stroke="#ccd6eb" stroke-width="1"></path><path class="highcharts-tick" d="M 456.5 319 L 456.5 329" fill="none" opacity="1" stroke="#ccd6eb" stroke-width="1"></path><path class="highcharts-tick" d="M 567.5 319 L 567.5 329" fill="none" opacity="1" stroke="#ccd6eb" stroke- ...
# <span>※ 국내 전체 충전기 수량 추정값(비공용 충전기 불포함)</span>
# </div>
# </div>
# </div>
# </div>
# <!--// contents -->
# </div>
# <!-- //wrap -->
# <!--// container -->
# <!--// contents e -->
# <iframe frameborder="0" height="0" id="defaultFrame" name="defaultFrame" title="업무 처리용 프레임" width="0"></iframe>
# </div>
# <!-- FOOTER s -->
# <script type="text/javascript">
# $(document).ready(function(){
# // 	$.ajax({
# // 	    method: "POST",
# // 	    url: "/cmmn/loginStat.do",
# // 	    data: {},
# // 	    contentType: "application/x-www-form-urlencoded; charset=utf-8",
# // 	    dataType: "json",
# // 	    success: function(data) {
# // 	   		$("#todayCnt").html(footerComma(data.todayCnt));
# // 	   		$("#monCnt").html(footerComma(data.monCnt));
# // 	   		$("#totCnt").html(footerComma(data.totCnt));
# // 	    },
# // 	    error: function(request,status,error) {
#
# // 	    }
# // 	});
# });
#
# function footerComma(num){
# 	num = String(num);
# 	return num.replace(/(\d)(?=(?:\d{3})+(?!\d))/g,'$1,');
# }
# </script>
# <div id="footer">
# <div class="foot_box">
# <div class="f_logo">
# <img alt="KEPCO" src="/publish/images/common/logo_foot.png"/>
# </div>
# <a href="/main/termsView.do">이용약관</a> <span class="t">|</span><a class="mar_l5" href="/main/popiView.do"><strong>개인정보처리방침</strong></a> <span class="t">|</span> <span class="m mar_l5">고객센터 1899-2100</span>
# <p class="mar_t5">사업자번호: 120-82-00052    대표자: 정승일   주소: (우) 58217 전라남도 나주시 전력로55 (빛가람동 120) <br/>
# 		Copyright@2016 KEPCO. All Rights Reserved </p>
# <!-- <div class="count_foot">
# 			<div class="daycount">금일방문자 :<span class="number" id="todayCnt"></span> 명</div>
# 			<div class="monthcount">당월방문자 :<span class="number" id="monCnt"></span> 명</div>
# 			<div class="totalcount">누적방문자 :<span class="number" id="totCnt"></span> 명</div>
# 		</div> -->
# <div class="f_logo02">
# <img alt="CHARGE LINK" src="/publish/com/images/roaimg_foot.png"/>
# </div>
# </div>
# </div>
# <!-- FOOTER e //-->
# <!--// wrapBody -->
# </div>
# <!--// wrapper -->
# </body></html>

# %%
# 제조사 이름 가져오기
factori_1 = []

for i in range(0, 10, 1):
    factori = soup.select('#contents > div > div.sub_tab_wrap2 > ul > li')
    factori_1.append(factori[i].text)
    
print(factori_1)
# Out:
# ['기아자동차', '현대자동차', '르노 삼성', 'BMW', '쉐보레', '닛산', 'Tesla', '쌍용', '벤츠', '한불모터스']

# %%
kia = [factori_1[0], factori_1[0] ,factori_1[0] ,factori_1[0]]
hundai = [factori_1[1],factori_1[1],factori_1[1],factori_1[1],factori_1[1],factori_1[1]]
samsung = [factori_1[2],factori_1[2]]
bmw = [factori_1[3],factori_1[3]]
che = [factori_1[4]]
nit = [factori_1[5]]
tesla = [factori_1[6],factori_1[6],factori_1[6]]
ssang = [factori_1[7]]
benz = [factori_1[8]]
hanbul = [factori_1[9],factori_1[9],factori_1[9]]

jejosa_list = [kia + hundai+ samsung+ bmw+ che+ nit+ tesla+ ssang+ benz+ hanbul]
jejosa = pd.DataFrame(jejosa_list[0])
jejosa
# Out:
#         0
# 0   기아자동차
# 1   기아자동차
# 2   기아자동차
# 3   기아자동차
# 4   현대자동차
# 5   현대자동차
# 6   현대자동차
# 7   현대자동차
# 8   현대자동차
# 9   현대자동차
# 10  르노 삼성
# 11  르노 삼성
# 12    BMW
# 13    BMW
# 14    쉐보레
# 15     닛산
# 16  Tesla
# 17  Tesla
# 18  Tesla
# 19     쌍용
# 20     벤츠
# 21  한불모터스
# 22  한불모터스
# 23  한불모터스

# %%
# 전기차 이름 가져오기
names = []

for i in range(0, 24, 1):
    name = soup.select('div.car_list_txt > h6')
    names.append(name[i].text)
    
print(names)
# Out:
# ['EV6', '니로EV', '쏘울 Booster', '봉고Ⅲ EV', '아이오닉5 (IONIQ)', 'GV60', 'GV70', 'G80', '아이오닉 (IONIQ)', '코나EV', 'SM3 ZE', 'ZOE EV', 'i3', 'iX3', '볼트(BOLT EV)', '리프 (LEAF)', '모델S', '모델3', '모델Y', '코란도 e-motion', 'EQA250', 'DS3 E-tense', 'Peugeot e-2008', 'Peugeot e-208']

# %%
car = pd.DataFrame(names)
car
# Out:
#                  0
# 0              EV6
# 1             니로EV
# 2       쏘울 Booster
# 3           봉고Ⅲ EV
# 4    아이오닉5 (IONIQ)
# 5             GV60
# 6             GV70
# 7              G80
# 8     아이오닉 (IONIQ)
# 9             코나EV
# 10          SM3 ZE
# 11          ZOE EV
# 12              i3
# 13             iX3
# 14     볼트(BOLT EV)
# 15       리프 (LEAF)
# 16             모델S
# 17             모델3
# 18             모델Y
# 19    코란도 e-motion
# 20          EQA250
# 21     DS3 E-tense
# 22  Peugeot e-2008
# 23   Peugeot e-208

# %%
# 전기차 스펙 가져오기
contants = []

for i in range(0, 144,1):
    contant = soup.select('div.car_list_txt > ul.blue_dot02 > li')
    contants.append(contant[i].text)

print(contants)
# Out:
# ['충전방식 : DC콤보', '승차인원 : 5인승', '1회충전 주행거리 : 483Km', '배터리 종류 : 리튬이온폴리머', '배터리 용량 : 77.5Kwh', '최고속도 : 185km/h', '충전방식 : DC콤보', '승차인원 : 5인승', '1회충전 주행거리 : 385Km', '배터리 종류 : 리튬이온폴리머', '배터리 용량 : 64Kwh', '최고속도 : 160km/h', '충전방식 : DC콤보', '승차인원 : 5인승', '1회충전 주행거리 : 391Km', '배터리 종류 : 리튬이온폴리머', '배터리 용량 : 64Kwh', '최고속도 : 155km/h', '충전방식 : DC콤보', '승차인원 : 3인승', '1회충전 주행거리 : 385Km', '배터리 종류 : 리튬이온폴리머', '배터리 용량 : 64Kwh', '최고속도 : 160km/h', '충전방식 : DC콤보', '승차인원 : 5인승', '1회충전 주행거리 : 423Km', '배터리 종류 : 리튬이온폴리머', '배터리 용량 : 72.6Kwh', '최고속도 : 185km/h', '충전방식 : DC콤보', '승차인원 : 5인승', '1회충전 주행거리 : 470Km', '배터리 종류 : 리튬이온폴리머', '배터리 용량 : 77.5Kwh', '최고속도 : 185km/h', '충전방식 : DC콤보', '승차인원 : 5인승', '1회충전 주행거리 : 408Km', '배터리 종류 : 리튬이온폴리머', '배터리 용량 : 77.5Kwh', '최고속도 : 235km/h', '충전방식 : DC콤보', '승차인원 : 5인승', '1회충전 주행거리 : 433Km', '배터리 종류 : 리튬이온폴리머', '배터리 용량 : 87.2Kwh', '최고속도 : 225km/h', '충전방식 : DC콤보', '승차인원 : 5인승', '1회충전 주행거리 : 271Km', '배터리 종류 : 리튬이온폴리머', '배터리 용량 : 38.3Kwh', '최고속도 : 165km/h', '충전방식 : DC콤보', '승차인원 : 5인승', '1회충전 주행거리 : 482Km', '배터리 종류 : 리튬이온폴리머', '배터리 용량 : 58.86Kwh', '최고속도 : 115km/h', '충전방식 : AC3상', '승차인원 : 4인승', '1회충전 주행거리 : 213Km', '배터리 종류 : 리튬이온폴리머', '배터리 용량 : 26.6Kwh', '최고속도 : 135km/h', '충전방식 : DC콤보', '승차인원 : 5인승', '1회충전 주행거리 : 309km', '배터리 종류 : 리튬이온', '배터리 용량 : 54.5Kwh', '최고속도 : 140km/h', '충전방식 : DC콤보', '승차인원 : 5인승', '1회충전 주행거리 : 248Km', '배터리 종류 : 리튬이온', '배터리 용량 : 37.9Kwh', '최고속도 : 150km/h', '충전방식 : DC콤보', '승차인원 : 5인승', '1회충전 주행거리 : 356.9km', '배터리 종류 : 리튬이온', '배터리 용량 : 80.04Kwh', '최고속도 : 180km/h', '충전방식 : DC콤보', '승차인원 : 5인승', '1회충전 주행거리 : 383km', '배터리 종류 : 리튬이온', '배터리 용량 : 60Kwh', '최고속도 : 154km/h', '충전방식 : 차데모', '승차인원 : 5인승', '1회충전 주행거리 : 172Km', '배터리 종류 : 리튬이온', '배터리 용량 : 40Kwh', '최고속도 : 140km/h', '충전방식 : AC3상', '승차인원 : 5인승', '1회충전 주행거리 : 378Km', '배터리 종류 : 리튬이온', '배터리 용량 : 90Kwh', '최고속도 : 250km/h', '충전방식 : 테슽라전용', '승차인원 : 5인승', '1회충전 주행거리 : 527Km', '배터리 종류 : 리튬이온', '배터리 용량 :84.96Kwh', '최고속도 : 233km/h', '충전방식 : 테슽라전용', '승차인원 : 5인승', '1회충전 주행거리 : 511Km', '배터리 종류 : 리튬이온', '배터리 용량 :84.96Kwh', '최고속도 : 217km/h', '충전방식 : DC콤보', '승차인원 : 5인승', '1회충전 주행거리 : 307Km', '배터리 종류 : 리튬이온', '배터리 용량 :61.4Kwh', '최고속도 : 163km/h', '충전방식 : DC콤보', '승차인원 : 5인승', '1회충전 주행거리 : 302.7Km', '배터리 종류 : 리튬이온', '배터리 용량 :61.4Kwh', '최고속도 : 160km/h', '충전방식 : DC콤보', '승차인원 : 5인승', '1회충전 주행거리 : 237Km', '배터리 종류 : 리튬이온', '배터리 용량 :47.4Kwh', '최고속도 : 150km/h', '충전방식 : DC콤보', '승차인원 : 5인승', '1회충전 주행거리 : 237Km', '배터리 종류 : 리튬이온', '배터리 용량 :47.4Kwh', '최고속도 : 150km/h', '충전방식 : DC콤보', '승차인원 : 5인승', '1회충전 주행거리 : 244Km', '배터리 종류 : 리튬이온', '배터리 용량 :47.4Kwh', '최고속도 : 150km/h']

# %%
# contants 내용을 주제별로 나눠서 차종마다 concat
for i in range(0, 6, 1):
    globals()['contants_{}'.format(i)] = []
    globals()['contants_{}'.format(i)] = contants[i:144:6]
    globals()['contants_{}'.format(i)] = pd.DataFrame(globals()['contants_{}'.format(i)])
    globals()['contants_{}'.format(i)] = globals()['contants_{}'.format(i)][0].str.split(' :').str[1]

ele_car = pd.concat([car, contants_0,contants_1,contants_2,contants_3,contants_4,contants_5], axis=1)
ele_car.columns = ['차명', '충전방식', '승차인원', '1회충전 주행거리', '배터리 종류', '배터리 용량', '최고속도']
ele_car
# Out:
#                 차명    충전방식  승차인원 1회충전 주행거리    배터리 종류     배터리 용량      최고속도
# 0              EV6    DC콤보   5인승     483Km   리튬이온폴리머    77.5Kwh   185km/h
# 1             니로EV    DC콤보   5인승     385Km   리튬이온폴리머      64Kwh   160km/h
# 2       쏘울 Booster    DC콤보   5인승     391Km   리튬이온폴리머      64Kwh   155km/h
# 3           봉고Ⅲ EV    DC콤보   3인승     385Km   리튬이온폴리머      64Kwh   160km/h
# 4    아이오닉5 (IONIQ)    DC콤보   5인승     423Km   리튬이온폴리머    72.6Kwh   185km/h
# 5             GV60    DC콤보   5인승     470Km   리튬이온폴리머    77.5Kwh   185km/h
# 6             GV70    DC콤보   5인승     408Km   리튬이온폴리머    77.5Kwh   235km/h
# 7              G80    DC콤보   5인승     433Km   리튬이온폴리머    87.2Kwh   225km/h
# 8     아이오닉 (IONIQ)    DC콤보   5인승     271Km   리튬이온폴리머    38.3Kwh   165km/h
# 9             코나EV    DC콤보   5인승     482Km   리튬이온폴리머   58.86Kwh   115km/h
# 10          SM3 ZE    AC3상   4인승     213Km   리튬이온폴리머    26.6Kwh   135km/h
# 11          ZOE EV    DC콤보   5인승     309km      리튬이온    54.5Kwh   140km/h
# 12              i3    DC콤보   5인승     248Km      리튬이온    37.9Kwh   150km/h
# 13             iX3    DC콤보   5인승   356.9km      리튬이온   80.04Kwh   180km/h
# 14     볼트(BOLT EV)    DC콤보   5인승     383km      리튬이온      60Kwh   154km/h
# 15       리프 (LEAF)     차데모   5인승     172Km      리튬이온      40Kwh   140km/h
# 16             모델S    AC3상   5인승     378Km      리튬이온      90Kwh   250km/h
# 17             모델3   테슽라전용   5인승     527Km      리튬이온   84.96Kwh   233km/h
# 18             모델Y   테슽라전용   5인승     511Km      리튬이온   84.96Kwh   217km/h
# 19    코란도 e-motion    DC콤보   5인승     307Km      리튬이온    61.4Kwh   163km/h
# 20          EQA250    DC콤보   5인승   302.7Km      리튬이온    61.4Kwh   160km/h
# 21     DS3 E-tense    DC콤보   5인승     237Km      리튬이온    47.4Kwh   150km/h
# 22  Peugeot e-2008    DC콤보   5인승     237Km      리튬이온    47.4Kwh   150km/h
# 23   Peugeot e-208    DC콤보   5인승     244Km      리튬이온    47.4Kwh   150km/h
