# %%
import pandas as pd
# csv파일 불러오기
csv = pd.read_csv('./data/부산충전소.csv', encoding='euc-kr')
csv.head(10)
# Out:
#              운영기관         충전소  충전기ID            충전기타입      지역   시군구  \
# 0  환경부(한국자동차환경협회)  kbs 부산방송총국      1  DC차데모+AC3상+DC콤보  부산광역시   수영구
# 1  환경부(한국자동차환경협회)  kbs 부산방송총국     11             DC콤보  부산광역시   수영구
# 2  환경부(한국자동차환경협회)  kbs 부산방송총국     12             DC콤보  부산광역시   수영구
# 3  환경부(한국자동차환경협회)     국립부산과학관     11             DC콤보  부산광역시   기장군
# 4  환경부(한국자동차환경협회)     국립부산과학관     12             DC콤보  부산광역시   기장군
# 5  환경부(한국자동차환경협회)        기장군청      1  DC차데모+AC3상+DC콤보  부산광역시   기장군
# 6  환경부(한국자동차환경협회)  기장시장 공영주차장      1  DC차데모+AC3상+DC콤보  부산광역시   기장군
# 7  환경부(한국자동차환경협회)   기장현대드림볼파크      1  DC차데모+AC3상+DC콤보  부산광역시   기장군
# 8  환경부(한국자동차환경협회)   기장현대드림볼파크     11             DC콤보  부산광역시   기장군
# 9  환경부(한국자동차환경협회)   기장현대드림볼파크     12             DC콤보  부산광역시   기장군
#
#                                  주소
# 0                 부산광역시 수영구 수영로 429
# 1                 부산광역시 수영구 수영로 429
# 2                 부산광역시 수영구 수영로 429
# 3             부산광역시 기장군 기장읍 석산리 293
# 4             부산광역시 기장군 기장읍 석산리 293
# ...

# %%
csv_1 = csv[['지역','주소']]
csv_1
# Out:
#           지역                                        주소
# 0     부산광역시                          부산광역시 수영구 수영로 429
# 1     부산광역시                          부산광역시 수영구 수영로 429
# 2     부산광역시                          부산광역시 수영구 수영로 429
# 3     부산광역시                      부산광역시 기장군 기장읍 석산리 293
# 4     부산광역시                      부산광역시 기장군 기장읍 석산리 293
# ...      ...                                       ...
# 6307  부산광역시   부산광역시 강서구 명지국제1로 56-1플러스타워(3598-2 플러스타워)
# 6308  부산광역시   부산광역시 강서구 명지국제1로 56-1플러스타워(3598-2 플러스타워)
# 6309  부산광역시        부산광역시 사하구 낙동대로 123휴마트괴정점(괴정동 358-1)
# 6310  부산광역시        부산광역시 사하구 낙동대로 123휴마트괴정점(괴정동 358-1)
# 6311  부산광역시        부산광역시 사하구 낙동대로 123휴마트괴정점(괴정동 358-1)
#
# [6312 rows x 2 columns]

# %%
csv[csv[['충전기타입','주소']].duplicated()]
# Out:
#                 운영기관                   충전소  충전기ID            충전기타입      지역  \
# 2     환경부(한국자동차환경협회)            kbs 부산방송총국     12             DC콤보  부산광역시
# 4     환경부(한국자동차환경협회)               국립부산과학관     12             DC콤보  부산광역시
# 9     환경부(한국자동차환경협회)             기장현대드림볼파크     12             DC콤보  부산광역시
# 11    환경부(한국자동차환경협회)            기장현대차드림볼파크      2             DC콤보  부산광역시
# 13    환경부(한국자동차환경협회)                  김해공항      2  DC차데모+AC3상+DC콤보  부산광역시
# ...              ...                   ...    ...              ...     ...
# 6305          한국전자금융  부산 플러스시네마 명지(플러스시네마)      2             AC완속  부산광역시
# 6306          한국전자금융  부산 플러스시네마 명지(플러스시네마)      3             AC완속  부산광역시
# 6308          한국전자금융              부산 플러스타워      2             AC완속  부산광역시
# 6310          한국전자금융             부산 휴마트괴정점      2             AC완속  부산광역시
# 6311          한국전자금융             부산 휴마트괴정점      3             AC완속  부산광역시
#
#        시군구                                                 주소
# ...

# %%
list = []
list = csv['주소'].value_counts()
list
# Out:
# 부산광역시 남구 분포로 111 (용호동)지하주차장                                  117
# 부산광역시 기장군 일광읍 해송1로 33일광신도시 비스타동원2차(동원 2차)                     40
# 부산광역시 해운대구 마린시티2로 33(우동, 해운대두산위브더제니스)(1407 해운대두산위브더제니스)       39
# 부산광역시 남구 분포로 145(954 더블유)                                     30
# 부산광역시 해운대구 좌동순환로433번길 30(중동, 해운대힐스테이트위브)(1818 해운대힐스테이트위브)     30
#                                                             ...
# 부산광역시 사상구 엄궁로 11 (엄궁동)옥외주차장                                    1
# 부산광역시 부산진구 새싹로 183 (연지동, 세동한신아파트) 101동~105동105동 다27기둥          1
# 부산광역시 부산진구 새싹로 183 (연지동, 세동한신아파트) 101동~105동103동지하 가63기둥        1
# 부산광역시 해운대구 좌동순환로 402(래미안 해운대)                                  1
# 부산광역시 사상구 낙동대로 1070 (감전동, 구덕주유소)                               1
# Name: 주소, Length: 1597, dtype: int64

# %%
list.index[0]
# Out:
# '부산광역시 남구 분포로 111 (용호동)지하주차장'

# %%
a = pd.DataFrame

# %%
for i in range(0, len(list), 1):
    a.append(list.index[i])

print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\STUDY\StudyPython22\220614~\11day~\1.ipynb Cell 7' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/220614~/11day~/1.ipynb#ch0000007?line=0'>1</a> for i in range(0, len(list), 1):
# ----> <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/220614~/11day~/1.ipynb#ch0000007?line=1'>2</a>     a.append(list.index[i])
#       <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/220614~/11day~/1.ipynb#ch0000007?line=3'>4</a> print(a)
#
# TypeError: append() missing 1 required positional argument: 'other'

# %%
a.append
