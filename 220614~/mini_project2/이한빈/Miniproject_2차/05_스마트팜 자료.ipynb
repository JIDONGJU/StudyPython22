# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/malgun.ttf"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
file_path = "./data/01_스마트팜 예산.csv"
df = pd.read_csv(file_path, encoding="EUC-KR", header=2)
df
# Out:
#                 구분 Unnamed: 1         2014         2015         2016  \
# 0      스마트농업 예산(A)        NaN          464          538          861
# 1            부 문 별     시설  보급  191\n(41.2)  229\n(42.6)  442\n(51.4)
# 2              NaN      산업인프라    43\n(9.3)    53\n(9.8)    53\n(6.2)
# 3              NaN       연구개발  230\n(49.5)  255\n(47.5)  365\n(42.4)
# 4           부 처\n별       농식품부          444          508          769
# 5              NaN        농진청           20           30           92
# 6  농식품부·농진청 총지출(B)        NaN      148,607      152,817      152,953
# 7          비중(A/B)        NaN         0.31         0.35         0.56
#
#           2017         2018           2019           2020           2021  \
# 0        1,101        1,324          2,613          3,440          3,183
# 1  581\n(52.8)  627\n(47.4)  1,097\n(42.0)  1,436\n(41.7)  1,025\n(32.2)
# 2    90\n(8.2)  158\n(11.9)    829\n(31.7)  1,185\n(34.5)  1,590\n(50.0)
# ...

# %%
df1 = df[['구분', '2014', '2015', '2016', '2017', '2018', '2019',
       '2020', '2021', '2022']].loc[:0]
df1
# Out:
#             구분 2014 2015 2016   2017   2018   2019   2020   2021   2022
# 0  스마트농업 예산(A)  464  538  861  1,101  1,324  2,613  3,440  3,183  3,044

# %%
df2 = df1.set_index("구분")

# %%
df3 = df2.T

# %%
df3["스마트농업 예산(A)"] = df3["스마트농업 예산(A)"].str.replace(",", "")

# %%
df4 = df3.T.astype(int)
df4
# Out:
#              2014  2015  2016  2017  2018  2019  2020  2021  2022
# 구분
# 스마트농업 예산(A)   464   538   861  1101  1324  2613  3440  3183  3044

# %%
plt.rcParams['figure.figsize'] = (30,15)
plt.rcParams['lines.linewidth'] = 2
plt.rc("font", family = "Malgun Gothic", size=10)
df4.T.plot(kind="bar", fontsize=20)

plt.title("스마트팜 농업 예산", fontsize=40)
plt.xlabel(" ", fontsize=20)
a = range(0,20,1)

plt.xticks(fontsize = 20, rotation=0)
plt.yticks(fontsize = 20)

plt.legend(labels=["단위 : 억원"],loc="upper right", fontsize=20)
plt.grid(True)

plt.show()

# %%
file_path = "./data/02_전체농가_스마트농업비중.csv"
data = pd.read_csv(file_path, encoding="EUC-KR", header=1)
data
# Out:
#                                                   구분         Unnamed: 1  \
# 0                                               스마트팜      스마트팜 (ha) (A)
# 1                                                NaN  전체  시설원예 (ha) (B)
# 2                                                NaN      비중\n(%) (A/B)
# 3                                             스마트 축사      스마트축사 (호) (C)
# 4                                                NaN      축산전업농 (호) (D)
# 5                                                NaN      비중\n(%) (C/D)
# 6  주:  전체 시설원예 면적은 농림축산식품부의 ?시설채소 온실현황 및 채소류 생산실적...                NaN
#
#      2014    2015    2016    2017    2018    2019    2020
# 0     405     769   1,912   4,010   4,900   5,383   5,985
# 1  54,168  55,015  54,218  54,632  53,274  54,118  54,526
# 2     0.7     1.4     3.5     7.3     9.2     9.9    11.0
# 3      23     181     430     801   1,425   2,390   3,463
# 4  32,768  30,128  33,177  34,415  33,377  34,957  29,695
# ...
