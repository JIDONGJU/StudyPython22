# %% [markdown]
# ### 빅데이터 스마트팜 API

# %%
######## 1단계 데이터 수집
import requests
apikey = "021e19b7e91646c5b8e404c792fc6eb4"
api = "http://www.smartfarmkorea.net/Agree_WS/webservices/ProvideRestService/getIdentityDataList/{key}"
url = api.format(key = apikey)
response = requests.get(url)
print(response.content)
# Out:
# b'[{"statusCode":"00","statusMessage":"NORMAL_CODE","userId":"LSDS_001","facilityId":"LSDS_001_01","addressName":"\xea\xb2\xbd\xec\x83\x81\xeb\x82\xa8\xeb\x8f\x84 \xed\x95\x98\xeb\x8f\x99\xea\xb5\xb0","itemCode":"413000"},{"statusCode":null,"statusMessage":null,"userId":"LSDS_002","facilityId":"LSDS_002_01","addressName":"\xec\xb6\xa9\xec\xb2\xad\xeb\x82\xa8\xeb\x8f\x84 \xec\xb2\x9c\xec\x95\x88\xec\x8b\x9c","itemCode":"413000"},{"statusCode":null,"statusMessage":null,"userId":"LSDS_003","facilityId":"LSDS_003_01","addressName":"\xec\xb6\xa9\xec\xb2\xad\xeb\x82\xa8\xeb\x8f\x84 \xec\xb2\x9c\xec\x95\x88\xec\x8b\x9c","itemCode":"413000"},{"statusCode":null,"statusMessage":null,"userId":"LSDS_005","facilityId":"LSDS_005_01","addressName":"\xea\xb2\xbd\xea\xb8\xb0\xeb\x8f\x84 \xec\x97\xac\xec\xa3\xbc\xea\xb5\xb0","itemCode":"413000"},{"statusCode":null,"statusMessage":null,"userId":"LSDS_006","facilityId":"LSDS_006_01","addressName":"\xea\xb2\xbd\xec\x83\x81\xeb\xb6\x81\xeb\x8f\x84 \xed\x8f\xac\xed\x95\xad\xec\x8b\x9c","itemCode":"413000"},{"statusCode":null,"statusMessage":null,"userId":"PFS_0000001","facilityId":"PFS_0000001_01","addressName":"\xea\xb2\xbd\xec\x83\x81\xeb\x82\xa8\xeb\x8f\x84 \xec\x82\xac\xec\xb2\x9c\xec\x8b\x9c","itemCode":"080300"},{"statusCode":null,"statusMessage":null,"userId":"PFS_0000002","facilityId":"PFS_0000002_01","addressName":"\xec\xa0\x84\xeb\x9d\xbc\xeb\xb6\x81\xeb\x8f\x84 \xea\xb9\x80\xec\xa0\x9c\xec\x8b\x9c","itemCode":"080300"},{"statusCode":null,"statusMessage":null,"userId":"PFS_0000003","facilityId":"PFS_0000003_01","addressName":"\xea\xb2\xbd\xec\x83\x81\xeb\x82\xa8\xeb\x8f\x84 \xed\x95\xa8\xec\x95\x88\xea\xb5\xb0","itemCode":"080300"},{"statusCode":null,"statusMessage":null,"userId":"PFS_0000004","facilityId":"PFS_0000004_01","addressName":"\xea\xb2\xbd\xec\x83\x81\xeb\x82\xa8\xeb\x8f\x84 \xec\xa7\x84\xec\xa3\xbc\xec\x8b\x9c","itemCode":"080300"},{"statusCode":null,"statusMessage":null,"userId":"PFS_0000005","facilityId":"PFS_0000005_01","addressName":"\xea\xb2\xbd\xec\x83\x81\xeb\x82\xa8\xeb\x8f\x84 \xec\xa7\x84\xec\xa3\xbc\xec\x8b\x9c","itemCode":"132600"},{"statusCode":null,"statusMessage":null,"userId":"PFS_0000006","facilityId":"PFS_0000006_01","addressName":"\xec\xa0\x84\xeb\x9d\xbc\xeb\xb6\x81\xeb\x8f\x84 \xec\x88\x9c\xec\xb0\xbd\xea\xb5\xb0","itemCode":"080300"},{"statusCode":null,"statusMessage":null,"userId":"PFS_0000007","facilityId":"PFS_0000007_01","addressName":"\xec\xa0\x84\xeb\x9d\xbc\xeb\x82\xa8\xeb\x8f\x84 \xed\x99\x94\xec\x88\x9c\xea\xb5\xb0","itemCode":"080300"},{"statusCode":null,"statusMessage":null,"userId":"PFS_0000008","facilityId":"PFS_0000008_01","addressName":"\xec\xa0\x84\xeb\x9d\xbc\xeb\xb6\x81\xeb\x8f\x84 \xec\x99\x84\xec\xa3\xbc\xea\xb5\xb0","itemCode":"080300"},{"statusCode":null,"statusMessage":null,"userId":"PFS_0000009","facilityId":"PFS_0000009_01","addressName":"\xec\xa0\x84\xeb\x9d\xbc\xeb\xb6\x81\xeb\x8f\x84 \xea\xb9\x80\xec\xa0\x9c\xec\x8b\x9c","itemCode":"080300"},{"statusCode":null,"statusMessage":null,"userId":"PFS_0000010","facilityId":"PFS_0000010_01","addressName":"\xea\xb2\xbd\xec\x83\x81\xeb\x82\xa8\xeb\x8f\x84 \xea\xb1\xb0\xec\xb0\xbd\xea\xb5\xb0","itemCode":"132600"},{"statusCode":null,"statusMessage":null,"userId":"PF_0000001","facilityId":"PF_0000001_01","addressName":"\xec\xb6\xa9\xec\xb2\xad\xeb\x82\xa8\xeb\x8f\x84 \xeb\xb6\x80\xec\x97\xac\xea\xb5\xb0","itemCode":"080400"},{"statusCode":null,"statusMessage":null,"userId":"PF_0000002","facilityId":"PF_0000002_01","addressName":"\xec\xb6\xa9\xec\xb2\xad\xeb\x82\xa8\xeb\x8f\x84 \xeb\xb6\x80\xec\x97\xac\xea\xb5\xb0","itemCode":"080300"},{"statusCode":null,"statusMessage":null,"userId":"PF_0000004","facilityId":"PF_0000004_01","addressName":"\xec\xb6\xa9\xec\xb2\xad\xeb\x82\xa8\xeb\x8f\x84 \xeb\xb6\x80\xec\x97\xac\xea\xb5\xb0","itemCode":"080300"},{"statusCode":null,"statusMessage":null,"userId":"PF_0000005","facilityId":"PF_0000005_01","addressName":"\xec\xb6\xa9\xec\xb2\xad\xeb\x82\xa8\xeb\x ...

# %%
######## 1단계 데이터 수집

import requests

apikey = "uFb4pLmlG2sXgnYdbOzN8xmN575trI8UwiTunNYE4hCzMzZXGxO5TVO3Eo33nCsEWrOLlBfWPVssKjnTlivC6Q%3D%3D"
pageNO=1
pageSize=10
searchFrmhsCode="TestFarm02"
searchMeasDt=2019010100

api = """http://apis.data.go.kr/1390000/SmartFarmdata/envdatarqst?serviceKey={key}&pageNO={no}&pageSize={row}&searchFrmhsCode={farmcode}&searchMeasDt={dt}&returnType=xml"""

url = api.format(no = pageNO,
                 row = pageSize,
                 farmcode = searchFrmhsCode,
                 dt = searchMeasDt,
                 key = apikey)

response = requests.get(url)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?>\n<response><header><resultCode>00</resultCode><resultMsg>OK</resultMsg></header><body><pageNo>1</pageNo><totalCount>0</totalCount><items></items><numOfRows>10</numOfRows></body></response>'

# %%
######## 2단계 ...html 형태로 의미 부여하기
from bs4 import BeautifulSoup
import requests

re = response.text
soup = BeautifulSoup(re, "html.parser") # html 문자열이 아닌 <> 형태로 표현
soup
# Out:
# {"response":{"header":{"resultCode":"00","resultMsg":"OK"},"body":{"pageNo":1,"totalCount":1,"items":{"item":[{"inTp":24.5,"inHd":78.9,"measDtStr":"20190101000000","otmsuplyqy":12.01,"acSlrdQy":1340.0,"frmhsId":"TestFarm01","cunt":4.0,"ph":5.8,"outTp":10.5,"outWs":1.2,"daysuplyqy":48.07,"inCo2":434.0,"ec":1.4}]},"numOfRows":10}},"resultCode":"","resultMessage":""}

# %%
import requests

apikey = "uFb4pLmlG2sXgnYdbOzN8xmN575trI8UwiTunNYE4hCzMzZXGxO5TVO3Eo33nCsEWrOLlBfWPVssKjnTlivC6Q%3D%3D"
pageNO=1
pageSize=10
searchFrmhsCode="TestFarm01"
searchMeasDt=2019010100

api = """http://apis.data.go.kr/1390000/SmartFarmdata/envdatarqst?serviceKey={key}&pageNO={no}&pageSize={row}&searchFrmhsCode={farmcode}&searchMeasDt={dt}&returnType=xml"""

for fcode in range(0, len(searchFrmhsCode)):
    url = api.format(no = pageNO,
                 row = pageSize,
                 farmcode = searchFrmhsCode[fcode],
                 dt = searchMeasDt,
                 key = apikey)
    
response = requests.get(url)

######## 3단계 
airportkor = soup.find_all("airportkor")
parkingairportcodename = soup.find_all("parkingairportcodename")
parkingcongestion = soup.find_all("parkingcongestion")
parkingcongestiondegree = soup.find_all("parkingcongestiondegree")
parkingoccupiedspace = soup.find_all("parkingoccupiedspace")
parkingtotalspace = soup.find_all("parkingtotalspace")
sysgetdate = soup.find_all("sysgetdate")
sysgettime = soup.find_all("sysgettime")

# for i in range(0, len(airportkor), 1):
#     print("공항이름", airportkor[i])
#     print("주차장명", parkingairportcodename[i])
#     print("혼잡도", parkingcongestion[i])
#     print("혼잡율", parkingcongestiondegree[i])
#     print("현재 주차대수", parkingoccupiedspace[i])
#     print("전체 주차공간", parkingtotalspace[i])
#     print("수집일자", sysgetdate[i])
#     print("수집시간", sysgettime[i])

list_all = []

for i in range(0, len(airportkor), 1) :
    list_all.append([airportkor[i].text, 
                    parkingairportcodename[i].text, 
                    parkingcongestion[i].text, 
                    parkingcongestiondegree[i].text,
                    parkingoccupiedspace[i].text,
                    parkingtotalspace[i].text, 
                    sysgetdate[i].text,
                    sysgettime[i].text])

list_all

########################
col_nm=["공항이름", "주차장명", "혼잡도", "혼잡율", 
        "현재 주차대수", "전체 주차공간", "수집일자", "수집시간"]

new_df = pd.DataFrame(list_all, columns=col_nm)
new_df
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?>\n<response><header><resultCode>00</resultCode><resultMsg>OK</resultMsg></header><body><pageNo>1</pageNo><totalCount>0</totalCount><items></items><numOfRows>10</numOfRows></body></response>'
