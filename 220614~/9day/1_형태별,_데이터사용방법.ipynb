# %% [markdown]
# - 데이터를 가져오는 방법
#     - 데이터 다운로드 ex) 공공데이터 포탈
#         - excel, csv, txt, tsv, json 파일을 주로 씀
#     - API
#         - 플로그램과 프로그램이 주고받는 방식
#         - 인증키와 정의된 문서 필수
#         - 태그방식
#     - 웹 크롤링
#         - 페이지 소스를 열어서 찾아서 긁어내야 함
#         - HTML 태그규칙, CSS규칙

# %% [markdown]
# ## 데이터수집 : 데이터 다운로드

# %%
# bicycle.csv 파일을 읽어 들인 후 조회
# 데이터프레임 변수 df1
import pandas as pd

file = './data/bicycle.csv'
df1 = pd.read_csv(file, encoding='euc-kr')
df1
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2    SPB-21097   2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3    SPB-22292   2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# ..         ...               ...    ...                ...    ...
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 416  SPB-17768   2019-11-15 9:31    103         망원역 2번출구 앞   14.0
# 417  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞   24.0
# 418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞   18.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리
# 0     2019-11-01 9:01        3         중랑센터    7.0  12.0  1100.0
# ...

# %%
# bicycle.xlsx 파일 읽어 들인 후 조회
# 변수명 df2
file2 = './data/bicycle.xlsx'
df2 = pd.read_excel(file2)
df2
# Out:
#          자전거번호                대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220 2019-11-01 08:48:31    646  장한평역 1번출구 (국민은행앞)    3.0
# 1    SPB-16216 2019-11-04 08:38:39    646  장한평역 1번출구 (국민은행앞)    2.0
# 2    SPB-21097 2019-11-04 08:46:37    646  장한평역 1번출구 (국민은행앞)    1.0
# 3    SPB-22292 2019-11-05 08:34:59    646  장한평역 1번출구 (국민은행앞)    1.0
# 4    SPB-07935 2019-11-05 12:29:00    512        뚝섬역 1번 출구 옆   11.0
# ..         ...                 ...    ...                ...    ...
# 415  SPB-12116 2019-11-15 04:22:13    112            극동방송국 앞    5.0
# 416  SPB-17768 2019-11-15 09:31:48    103         망원역 2번출구 앞   14.0
# 417  SPB-18841 2019-11-15 20:40:40    113       홍대입구역 2번출구 앞   24.0
# 418  SPB-24467 2019-11-15 21:55:13    152         마포구민체육센터 앞   18.0
# 419  SPB-17570 2019-11-15 22:16:08    391              정동길입구    7.0
#
#                    반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리
# 0   2019-11-01 09:01:24        3         중랑센터    7.0  12.0  1100.0
# ...

# %%
file3 = './data/read.json'
df3 = pd.read_json(file3)
df3
# Out:
#   1.FirstName 2.LastName  3.Age       4.University  \
# 0     Gildong       Hong     20  Gachon University
# 1     Gildong       Hong     20  Gachon University
#
#                                            5.Courses
# 0  {'Classes': ['Probability', 'Generalized Linea...
# 1  {'Classes': ['Data Structure', 'Programming', ...

# %%
# df1 저장하기
# 저장위치 : data2 폴더
# 저장파일명 : sample_data.csv

df1.to_csv('./data2/sample_data.csv')

# %%
# df2 저장하기
# 저장위치 : data2 폴더
# 저장파일명 : sample_data.xlsx

df2.to_excel('./data2/sample_data.xlsx')

# %%
# df3 저장하기
# 저장위치 : data2 폴더
# 저장파일명 : sample_data.json

df3.to_json('./data2/sample_data.json')

# %% [markdown]
# ## 데이터수집 : OpenAPI 방식

# %% [markdown]
# ### 약국데이터

# %%
import requests

apikey = 'PJxL%2BXY%2F3jCY4HSnB6mvwYVVe%2FRjjeO2Mh0HsQUsNo%2FrFTh3m87PBCzUhIEDInkArvhb5jRrWxzoq5JWW97Eow%3D%3D'

pageNo = 1
numOfRows = 10
sidoCd = 110000
sgguCd=110019
emdongNm = '신내동'
yadmNm = '온누리'
xPos = 127.0965441345503
yPos=37.60765568913871
radius=3000



api = "http://apis.data.go.kr/B551182/pharmacyInfoService/getParmacyBasisList?pageNo={no}&numOfRows={row}&sidoCd={sido}&sgguCd={sigu}&emdongNm={dong}&yadmNm={yanm}&xPos={x}&yPos={y}&radius={r}&ServiceKey={key}"

url = api.format(no=pageNo,
                row=numOfRows,
                sido=sidoCd,
                sigu=sgguCd,
                dong=emdongNm,
                yanm=yadmNm,
                x=xPos,
                y=yPos,
                r=radius,
                key = apikey)


response = requests.get(url)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><addr>\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c \xec\xa4\x91\xeb\x9e\x91\xea\xb5\xac \xeb\xb4\x89\xed\x99\x94\xec\x82\xb0\xeb\xa1\x9c 215 1\xec\xb8\xb5 (\xec\x8b\xa0\xeb\x82\xb4\xeb\x8f\x99)</addr><clCd>81</clCd><clCdNm>\xec\x95\xbd\xea\xb5\xad</clCdNm><distance>.5478450769582605437588497466708942455</distance><emdongNm>\xec\x8b\xa0\xeb\x82\xb4\xeb\x8f\x99</emdongNm><estbDd>20001222</estbDd><postNo>02054</postNo><sgguCd>110019</sgguCd><sgguCdNm>\xec\xa4\x91\xeb\x9e\x91\xea\xb5\xac</sgguCdNm><sidoCd>110000</sidoCd><sidoCdNm>\xec\x84\x9c\xec\x9a\xb8</sidoCdNm><telno>02-3422-3097</telno><XPos>127.0965492</XPos><YPos>37.6076585</YPos><yadmNm>\xec\x98\xa8\xeb\x88\x84\xeb\xa6\xac\xea\xb1\xb4\xea\xb0\x95\xec\x95\xbd\xea\xb5\xad</yadmNm><ykiho>JDQ4MTg4MSM1MSMkMSMkNCMkMDMkMzgxOTYxIzExIyQxIyQ3IyQ4MiQyNjEyMjIjO
# ...

# %%
from bs4 import BeautifulSoup
import requests

# %%
re = response.text
re
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><addr>서울특별시 중랑구 봉화산로 215 1층 (신내동)</addr><clCd>81</clCd><clCdNm>약국</clCdNm><distance>.5478450769582605437588497466708942455</distance><emdongNm>신내동</emdongNm><estbDd>20001222</estbDd><postNo>02054</postNo><sgguCd>110019</sgguCd><sgguCdNm>중랑구</sgguCdNm><sidoCd>110000</sidoCd><sidoCdNm>서울</sidoCdNm><telno>02-3422-3097</telno><XPos>127.0965492</XPos><YPos>37.6076585</YPos><yadmNm>온누리건강약국</yadmNm><ykiho>JDQ4MTg4MSM1MSMkMSMkNCMkMDMkMzgxOTYxIzExIyQxIyQ3IyQ4MiQyNjEyMjIjODEjJDEjJDYjJDgz</ykiho></item><item><addr>서울특별시 중랑구 신내로 211 212호 (신내동, 금강리빙스텔)</addr><clCd>81</clCd><clCdNm>약국</clCdNm><distance>1035.1855820788666820304486290002772234</distance><emdongNm>신내동</emdongNm><estbDd>20140630</estbDd><postNo>02024</postNo><sgguCd>110019</sgguCd><sgguCdNm>중랑구</sgguCdNm><sidoCd>110000</sidoCd><sidoCdNm>서울</sidoCdNm><telno>02-6743-4262</
# ...

# %%
soup = BeautifulSoup(re, 'html.parser')
soup
# Out:
# c:\DEV\Langs\Python\Python39\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# ...

# %%
addr_list = soup.find_all('addr')
telno_list = soup.find_all('telno')
addr_list
# Out:
# [<addr>서울특별시 중랑구 봉화산로 215 1층 (신내동)</addr>,
#  <addr>서울특별시 중랑구 신내로 211 212호 (신내동, 금강리빙스텔)</addr>]

# %%
for i in range(0, len(addr_list), 1):
    print("약국위치 : ",addr_list[i].text)
    print("전화번호 : ",telno_list[i].text)
# Out:
# 약국위치 :  서울특별시 중랑구 봉화산로 215 1층 (신내동)
# 전화번호 :  02-3422-3097
# 약국위치 :  서울특별시 중랑구 신내로 211 212호 (신내동, 금강리빙스텔)
# 전화번호 :  02-6743-4262

# %%
# 약국이름, 시도명, 주소, 전화번호 에 대한 text 값만 추출하여
# 각각의 리스트에 담기.. 변수명은 아래처럼
# yad_txt_list, sido_txt_list, addr_txt_list, telno_txt_list
yadmnm_list = soup.find_all('yadmnm')
sidocdnm_list = soup.find_all('sidocdnm')
addr_list = soup.find_all('addr')
telno_list = soup.find_all('telno')
yad_txt_list = []
sido_txt_list = []
addr_txt_list = []
telno_txt_list = []

for i in range(0, len(addr_list), 1):
    yad_txt_list.append(yadmnm_list[i].text)
    sido_txt_list.append(sidocdnm_list[i].text)
    addr_txt_list.append(addr_list[i].text)
    telno_txt_list.append(telno_list[i].text)

# print(yad_txt_list)
# print(sido_txt_list)
# print(addr_txt_list)
# print(telno_txt_list)

df_temp = pd.DataFrame({'약국이름' : yad_txt_list,
                        '시도명' : sido_txt_list,
                        '주소' : addr_txt_list,
                        '전화번호' : telno_txt_list})
df_temp
# Out:
#       약국이름 시도명                                    주소          전화번호
# 0  온누리건강약국  서울           서울특별시 중랑구 봉화산로 215 1층 (신내동)  02-3422-3097
# 1  송이온누리약국  서울  서울특별시 중랑구 신내로 211 212호 (신내동, 금강리빙스텔)  02-6743-4262

# %%
# 아래와 같이 각각의 값들을 2차원 리스트 형태로 저장해 주세요
# 변수면 list_all
# [[유심약국, 서울, 서울특별시 ~ , 02-3422-2755],
# [서울동산약국, 서울, 서울특별시 ~ , 3432-0808]]

for i in range(0 , len(yad_txt_list), 1):
    list_all = [yad_txt_list[i] + sido_txt_list[i] + addr_txt_list[i] + telno_txt_list[i]]
    print(list_all)
    
    for i in range(0, len(list_all), 1):
        list_all = list_all.append(list_all[i])

    print(list)
# Out:
# ['온누리건강약국서울서울특별시 중랑구 봉화산로 215 1층 (신내동)02-3422-3097']
# <class 'list'>
# ['송이온누리약국서울서울특별시 중랑구 신내로 211 212호 (신내동, 금강리빙스텔)02-6743-4262']
# <class 'list'>

# %%
list_all = []
for i in range(0, len(yad_txt_list), 1):
    list_all.append([yadmnm_list[i].text, sidocdnm_list[i].text, addr_list[i].text, telno_list[i].text])
list_all

col_nm=['약국이름', '시도명', '주소', '전화번호']
new_df = pd.DataFrame(list_all, columns=col_nm)
new_df
# Out:
#       약국이름 시도명                                    주소          전화번호
# 0  온누리건강약국  서울           서울특별시 중랑구 봉화산로 215 1층 (신내동)  02-3422-3097
# 1  송이온누리약국  서울  서울특별시 중랑구 신내로 211 212호 (신내동, 금강리빙스텔)  02-6743-4262

# %% [markdown]
# ### 한국항공공사 주차장 API

# %%
codelist = ['GMP','PUS','CJU','TAE','KWJ','RSU','USN','KUV']
codelist[0]
# Out:
# 'GMP'

# %%
apikey = "PVdeh44WlF%2BHj6bGzfI2BXUldlea7Ggo%2FjjXvhbHCMNNFotchb2byGTopt4uAFS07RQzqmeU3M2Y8HcMmlYW9w%3D%3D"

codelist = ['GMP','PUS','CJU','TAE','KWJ','RSU','USN','KUV']
schAirportCode='GMP'

numOfRows=10
pageNo=1
airportEng=0
airportKor=0
parkingAirport=0
parkingCongestion=0
parkingCongestionDegree=0
parkingOccupiedSpace=0
parkingTotalSpace=0

api = "http://openapi.airport.co.kr/service/rest/AirportParkingCongestion/airportParkingCongestionRT?schAirportCode={code}&serviceKey={key}&numOfRows={row}&pageNo={no}&airportEng={eng}&airportKor={kor}&parkingAirport={pa}&parkingCongestion={pc}&parkingCongestionDegree={pcd}&parkingOccupiedSpace={pos}&parkingTotalSpace={pts}"

for i in range(0, len(codelist), 1):
    globals()['url{}'.format(i)] = api.format(code = codelist[i],
                                              key = apikey,
                                              row = numOfRows,
                                              no = pageNo,
                                              eng = airportEng,
                                              kor = airportKor,
                                              pa = parkingAirport,
                                              pc = parkingCongestion,
                                              pcd = parkingCongestionDegree,
                                              pos = parkingOccupiedSpace,
                                              pts = parkingTotalSpace)

# %%
for i in range(0 , 8 , 1):
    print(globals()['url{}'.format(i)])
# Out:
# http://openapi.airport.co.kr/service/rest/AirportParkingCongestion/airportParkingCongestionRT?schAirportCode=GMP&serviceKey=PVdeh44WlF%2BHj6bGzfI2BXUldlea7Ggo%2FjjXvhbHCMNNFotchb2byGTopt4uAFS07RQzqmeU3M2Y8HcMmlYW9w%3D%3D&numOfRows=10&pageNo=1&airportEng=0&airportKor=0&parkingAirport=0&parkingCongestion=0&parkingCongestionDegree=0&parkingOccupiedSpace=0&parkingTotalSpace=0
# http://openapi.airport.co.kr/service/rest/AirportParkingCongestion/airportParkingCongestionRT?schAirportCode=PUS&serviceKey=PVdeh44WlF%2BHj6bGzfI2BXUldlea7Ggo%2FjjXvhbHCMNNFotchb2byGTopt4uAFS07RQzqmeU3M2Y8HcMmlYW9w%3D%3D&numOfRows=10&pageNo=1&airportEng=0&airportKor=0&parkingAirport=0&parkingCongestion=0&parkingCongestionDegree=0&parkingOccupiedSpace=0&parkingTotalSpace=0
# ...

# %%
response0 = requests.get(url0)
response1 = requests.get(url1)
response2 = requests.get(url2)
response3 = requests.get(url3)
response4 = requests.get(url4)
response5 = requests.get(url5)
response6 = requests.get(url6)
response7 = requests.get(url7)

# %%
re0 = response0.text
re1 = response1.text
re2 = response2.text
re3 = response3.text
re4 = response4.text
re5 = response5.text
re6 = response6.text
re7 = response7.text

# %%
re = response.text
re
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><airportEng>GIMPO INTERNATIONAL AIRPORT</airportEng><airportKor>김포국제공항</airportKor><parkingAirportCodeName>[상세]예약주차장</parkingAirportCodeName><parkingCongestion>원활</parkingCongestion><parkingCongestionDegree>15.66%</parkingCongestionDegree><parkingOccupiedSpace>52</parkingOccupiedSpace><parkingTotalSpace>332</parkingTotalSpace><sysGetdate>2022-06-20</sysGetdate><sysGettime>14:48:03</sysGettime></item><item><airportEng>GIMPO INTERNATIONAL AIRPORT</airportEng><airportKor>김포국제공항</airportKor><parkingAirportCodeName>국내선 제1주차장</parkingAirportCodeName><parkingCongestion>혼잡</parkingCongestion><parkingCongestionDegree>91.53%</parkingCongestionDegree><parkingOccupiedSpace>2086</parkingOccupiedSpace><parkingTotalSpace>2279</parkingTotalSpace><sysGetdate>2022-06-20</sysGetdate><sysGettime>14:48:03</sysGettime></item><item><airportEn
# ...

# %%
soup0 = BeautifulSoup(re0, 'html.parser')
soup1 = BeautifulSoup(re1, 'html.parser')
soup2 = BeautifulSoup(re2, 'html.parser')
soup3 = BeautifulSoup(re3, 'html.parser')
soup4 = BeautifulSoup(re4, 'html.parser')
soup5 = BeautifulSoup(re5, 'html.parser')
soup6 = BeautifulSoup(re6, 'html.parser')
soup7 = BeautifulSoup(re7, 'html.parser')
soup
# Out:
# c:\DEV\Langs\Python\Python39\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# ...

# %%
eng_list = soup0.find_all('airporteng')
kor_list = soup0.find_all('airportkor')
pa_list = soup0.find_all('parkingairportcodename')
pc_list = soup0.find_all('parkingcongestion')
pcd_list = soup0.find_all('parkingcongestiondegree')
pos_list = soup0.find_all('parkingoccupiedspace')
pts_list = soup0.find_all('parkingtotalspace')

# print(kor_list)

eng_list_txt = []
kor_list_txt = []
pa_list_txt = []
pc_list_txt = []
pcd_list_txt = []
pos_list_txt = []
pts_list_txt = []

for i in range(0, len(eng_list), 1):
    eng_list_txt.append(eng_list[i].text)
    kor_list_txt.append(kor_list[i].text)
    pa_list_txt.append(pa_list[i].text)
    pc_list_txt.append(pc_list[i].text)
    pcd_list_txt.append(pcd_list[i].text)
    pos_list_txt.append(pos_list[i].text)
    pts_list_txt.append(pts_list[i].text)

# print(eng_list_txt)
# print(kor_list_txt)
# print(pa_list_txt)
# print(pc_list_txt)
# print(pcd_list_txt)
# print(pos_list_txt)
# print(pts_list_txt)

df_temp0 = pd.DataFrame({'공항명(영문)' : eng_list_txt,
                        '공항명(한글)' : kor_list_txt,
                        '주차장명' : pa_list_txt,
                        '주차장혼잡정도' : pc_list_txt,
                        '주차장혼잡률' : pcd_list_txt,
                        '입고된차량수' : pos_list_txt,
                        '전체주차면수' : pts_list_txt})
df_temp0
# Out:
#                        공항명(영문) 공항명(한글)       주차장명 주차장혼잡정도  주차장혼잡률 입고된차량수  \
# 0  GIMPO INTERNATIONAL AIRPORT  김포국제공항  [상세]예약주차장      원활  16.87%     56
# 1  GIMPO INTERNATIONAL AIRPORT  김포국제공항  국내선 제1주차장      혼잡  90.22%   2056
# 2  GIMPO INTERNATIONAL AIRPORT  김포국제공항  국내선 제2주차장      원활  87.69%   1531
# 3  GIMPO INTERNATIONAL AIRPORT  김포국제공항   국제선 주차빌딩      원활      0%      0
# 4  GIMPO INTERNATIONAL AIRPORT  김포국제공항  국제선 지하주차장      원활  18.75%    225
# 5  GIMPO INTERNATIONAL AIRPORT  김포국제공항   화물청사 주차장      원활  54.88%    624
#
#   전체주차면수
# 0    332
# 1   2279
# 2   1746
# 3    567
# 4   1200
# 5   1137

# %%
eng_list = soup1.find_all('airporteng')
kor_list = soup1.find_all('airportkor')
pa_list = soup1.find_all('parkingairportcodename')
pc_list = soup1.find_all('parkingcongestion')
pcd_list = soup1.find_all('parkingcongestiondegree')
pos_list = soup1.find_all('parkingoccupiedspace')
pts_list = soup1.find_all('parkingtotalspace')

# print(kor_list)

eng_list_txt = []
kor_list_txt = []
pa_list_txt = []
pc_list_txt = []
pcd_list_txt = []
pos_list_txt = []
pts_list_txt = []

for i in range(0, len(eng_list), 1):
    eng_list_txt.append(eng_list[i].text)
    kor_list_txt.append(kor_list[i].text)
    pa_list_txt.append(pa_list[i].text)
    pc_list_txt.append(pc_list[i].text)
    pcd_list_txt.append(pcd_list[i].text)
    pos_list_txt.append(pos_list[i].text)
    pts_list_txt.append(pts_list[i].text)

# print(eng_list_txt)
# print(kor_list_txt)
# print(pa_list_txt)
# print(pc_list_txt)
# print(pcd_list_txt)
# print(pos_list_txt)
# print(pts_list_txt)

df_temp1 = pd.DataFrame({'공항명(영문)' : eng_list_txt,
                        '공항명(한글)' : kor_list_txt,
                        '주차장명' : pa_list_txt,
                        '주차장혼잡정도' : pc_list_txt,
                        '주차장혼잡률' : pcd_list_txt,
                        '입고된차량수' : pos_list_txt,
                        '전체주차면수' : pts_list_txt})
df_temp1
# Out:
#                         공항명(영문) 공항명(한글)         주차장명 주차장혼잡정도  주차장혼잡률 입고된차량수  \
# 0  GIMHAE INTERNATIONAL AIRPORT  김해국제공항      P1여객주차장      원활   62.6%   1466
# 1  GIMHAE INTERNATIONAL AIRPORT  김해국제공항      P2여객주차장      원활  61.46%   1102
# 2  GIMHAE INTERNATIONAL AIRPORT  김해국제공항  P3여객(화물)주차장      원활   43.7%    430
# 3  GIMHAE INTERNATIONAL AIRPORT  김해국제공항  P4여객(화물)주차장      원활  69.37%    462
#
#   전체주차면수
# 0   2342
# 1   1793
# 2    984
# 3    666

# %%
eng_list = soup2.find_all('airporteng')
kor_list = soup2.find_all('airportkor')
pa_list = soup2.find_all('parkingairportcodename')
pc_list = soup2.find_all('parkingcongestion')
pcd_list = soup2.find_all('parkingcongestiondegree')
pos_list = soup2.find_all('parkingoccupiedspace')
pts_list = soup2.find_all('parkingtotalspace')

# print(kor_list)

eng_list_txt = []
kor_list_txt = []
pa_list_txt = []
pc_list_txt = []
pcd_list_txt = []
pos_list_txt = []
pts_list_txt = []

for i in range(0, len(eng_list), 1):
    eng_list_txt.append(eng_list[i].text)
    kor_list_txt.append(kor_list[i].text)
    pa_list_txt.append(pa_list[i].text)
    pc_list_txt.append(pc_list[i].text)
    pcd_list_txt.append(pcd_list[i].text)
    pos_list_txt.append(pos_list[i].text)
    pts_list_txt.append(pts_list[i].text)

# print(eng_list_txt)
# print(kor_list_txt)
# print(pa_list_txt)
# print(pc_list_txt)
# print(pcd_list_txt)
# print(pos_list_txt)
# print(pts_list_txt)

df_temp2 = pd.DataFrame({'공항명(영문)' : eng_list_txt,
                        '공항명(한글)' : kor_list_txt,
                        '주차장명' : pa_list_txt,
                        '주차장혼잡정도' : pc_list_txt,
                        '주차장혼잡률' : pcd_list_txt,
                        '입고된차량수' : pos_list_txt,
                        '전체주차면수' : pts_list_txt})
df_temp2
# Out:
#                       공항명(영문) 공항명(한글) 주차장명 주차장혼잡정도  주차장혼잡률 입고된차량수 전체주차면수
# 0  JEJU INTERNATIONAL AIRPORT  제주국제공항   여객      혼잡  93.98%   1747   1859
# 1  JEJU INTERNATIONAL AIRPORT  제주국제공항   화물      원활   4.93%     15    304

# %%
eng_list = soup3.find_all('airporteng')
kor_list = soup3.find_all('airportkor')
pa_list = soup3.find_all('parkingairportcodename')
pc_list = soup3.find_all('parkingcongestion')
pcd_list = soup3.find_all('parkingcongestiondegree')
pos_list = soup3.find_all('parkingoccupiedspace')
pts_list = soup3.find_all('parkingtotalspace')

# print(kor_list)

eng_list_txt = []
kor_list_txt = []
pa_list_txt = []
pc_list_txt = []
pcd_list_txt = []
pos_list_txt = []
pts_list_txt = []

for i in range(0, len(eng_list), 1):
    eng_list_txt.append(eng_list[i].text)
    kor_list_txt.append(kor_list[i].text)
    pa_list_txt.append(pa_list[i].text)
    pc_list_txt.append(pc_list[i].text)
    pcd_list_txt.append(pcd_list[i].text)
    pos_list_txt.append(pos_list[i].text)
    pts_list_txt.append(pts_list[i].text)

# print(eng_list_txt)
# print(kor_list_txt)
# print(pa_list_txt)
# print(pc_list_txt)
# print(pcd_list_txt)
# print(pos_list_txt)
# print(pts_list_txt)

df_temp3 = pd.DataFrame({'공항명(영문)' : eng_list_txt,
                        '공항명(한글)' : kor_list_txt,
                        '주차장명' : pa_list_txt,
                        '주차장혼잡정도' : pc_list_txt,
                        '주차장혼잡률' : pcd_list_txt,
                        '입고된차량수' : pos_list_txt,
                        '전체주차면수' : pts_list_txt})
df_temp3
# Out:
#                        공항명(영문) 공항명(한글)   주차장명 주차장혼잡정도  주차장혼잡률 입고된차량수 전체주차면수
# 0  DAEGU INTERNATIONAL AIRPORT  대구국제공항     일반      원활  74.34%   1037   1395
# 1  DAEGU INTERNATIONAL AIRPORT  대구국제공항  화물주차장      원활      0%      0     34

# %%
eng_list = soup4.find_all('airporteng')
kor_list = soup4.find_all('airportkor')
pa_list = soup4.find_all('parkingairportcodename')
pc_list = soup4.find_all('parkingcongestion')
pcd_list = soup4.find_all('parkingcongestiondegree')
pos_list = soup4.find_all('parkingoccupiedspace')
pts_list = soup4.find_all('parkingtotalspace')

# print(kor_list)

eng_list_txt = []
kor_list_txt = []
pa_list_txt = []
pc_list_txt = []
pcd_list_txt = []
pos_list_txt = []
pts_list_txt = []

for i in range(0, len(eng_list), 1):
    eng_list_txt.append(eng_list[i].text)
    kor_list_txt.append(kor_list[i].text)
    pa_list_txt.append(pa_list[i].text)
    pc_list_txt.append(pc_list[i].text)
    pcd_list_txt.append(pcd_list[i].text)
    pos_list_txt.append(pos_list[i].text)
    pts_list_txt.append(pts_list[i].text)

# print(eng_list_txt)
# print(kor_list_txt)
# print(pa_list_txt)
# print(pc_list_txt)
# print(pcd_list_txt)
# print(pos_list_txt)
# print(pts_list_txt)

df_temp4 = pd.DataFrame({'공항명(영문)' : eng_list_txt,
                        '공항명(한글)' : kor_list_txt,
                        '주차장명' : pa_list_txt,
                        '주차장혼잡정도' : pc_list_txt,
                        '주차장혼잡률' : pcd_list_txt,
                        '입고된차량수' : pos_list_txt,
                        '전체주차면수' : pts_list_txt})
df_temp4
# Out:
#            공항명(영문) 공항명(한글)   주차장명 주차장혼잡정도 주차장혼잡률 입고된차량수 전체주차면수
# 0  GWANGJU AIRPORT    광주공항  제1주차장      만차   100%    540    540
# 1  GWANGJU AIRPORT    광주공항  제2주차장      만차   100%    400    400

# %%
eng_list = soup5.find_all('airporteng')
kor_list = soup5.find_all('airportkor')
pa_list = soup5.find_all('parkingairportcodename')
pc_list = soup5.find_all('parkingcongestion')
pcd_list = soup5.find_all('parkingcongestiondegree')
pos_list = soup5.find_all('parkingoccupiedspace')
pts_list = soup5.find_all('parkingtotalspace')

# print(kor_list)

eng_list_txt = []
kor_list_txt = []
pa_list_txt = []
pc_list_txt = []
pcd_list_txt = []
pos_list_txt = []
pts_list_txt = []

for i in range(0, len(eng_list), 1):
    eng_list_txt.append(eng_list[i].text)
    kor_list_txt.append(kor_list[i].text)
    pa_list_txt.append(pa_list[i].text)
    pc_list_txt.append(pc_list[i].text)
    pcd_list_txt.append(pcd_list[i].text)
    pos_list_txt.append(pos_list[i].text)
    pts_list_txt.append(pts_list[i].text)

# print(eng_list_txt)
# print(kor_list_txt)
# print(pa_list_txt)
# print(pc_list_txt)
# print(pcd_list_txt)
# print(pos_list_txt)
# print(pts_list_txt)

df_temp5 = pd.DataFrame({'공항명(영문)' : eng_list_txt,
                        '공항명(한글)' : kor_list_txt,
                        '주차장명' : pa_list_txt,
                        '주차장혼잡정도' : pc_list_txt,
                        '주차장혼잡률' : pcd_list_txt,
                        '입고된차량수' : pos_list_txt,
                        '전체주차면수' : pts_list_txt})
df_temp5
# Out:
#          공항명(영문) 공항명(한글)   주차장명 주차장혼잡정도 주차장혼잡률 입고된차량수 전체주차면수
# 0  YEOSU AIRPORT    여수공항  제1주차장      원활  81.2%    337    415
# 1  YEOSU AIRPORT    여수공항  제2주차장      원활  75.6%    158    209

# %%
eng_list = soup6.find_all('airporteng')
kor_list = soup6.find_all('airportkor')
pa_list = soup6.find_all('parkingairportcodename')
pc_list = soup6.find_all('parkingcongestion')
pcd_list = soup6.find_all('parkingcongestiondegree')
pos_list = soup6.find_all('parkingoccupiedspace')
pts_list = soup6.find_all('parkingtotalspace')

# print(kor_list)

eng_list_txt = []
kor_list_txt = []
pa_list_txt = []
pc_list_txt = []
pcd_list_txt = []
pos_list_txt = []
pts_list_txt = []

for i in range(0, len(eng_list), 1):
    eng_list_txt.append(eng_list[i].text)
    kor_list_txt.append(kor_list[i].text)
    pa_list_txt.append(pa_list[i].text)
    pc_list_txt.append(pc_list[i].text)
    pcd_list_txt.append(pcd_list[i].text)
    pos_list_txt.append(pos_list[i].text)
    pts_list_txt.append(pts_list[i].text)

# print(eng_list_txt)
# print(kor_list_txt)
# print(pa_list_txt)
# print(pc_list_txt)
# print(pcd_list_txt)
# print(pos_list_txt)
# print(pts_list_txt)

df_temp6 = pd.DataFrame({'공항명(영문)' : eng_list_txt,
                        '공항명(한글)' : kor_list_txt,
                        '주차장명' : pa_list_txt,
                        '주차장혼잡정도' : pc_list_txt,
                        '주차장혼잡률' : pcd_list_txt,
                        '입고된차량수' : pos_list_txt,
                        '전체주차면수' : pts_list_txt})
df_temp6
# Out:
#          공항명(영문) 공항명(한글) 주차장명 주차장혼잡정도  주차장혼잡률 입고된차량수 전체주차면수
# 0  ULSAN AIRPORT    울산공항   일반      원활  58.68%    267    455

# %%
eng_list = soup7.find_all('airporteng')
kor_list = soup7.find_all('airportkor')
pa_list = soup7.find_all('parkingairportcodename')
pc_list = soup7.find_all('parkingcongestion')
pcd_list = soup7.find_all('parkingcongestiondegree')
pos_list = soup7.find_all('parkingoccupiedspace')
pts_list = soup7.find_all('parkingtotalspace')

# print(kor_list)

eng_list_txt = []
kor_list_txt = []
pa_list_txt = []
pc_list_txt = []
pcd_list_txt = []
pos_list_txt = []
pts_list_txt = []

for i in range(0, len(eng_list), 1):
    eng_list_txt.append(eng_list[i].text)
    kor_list_txt.append(kor_list[i].text)
    pa_list_txt.append(pa_list[i].text)
    pc_list_txt.append(pc_list[i].text)
    pcd_list_txt.append(pcd_list[i].text)
    pos_list_txt.append(pos_list[i].text)
    pts_list_txt.append(pts_list[i].text)

# print(eng_list_txt)
# print(kor_list_txt)
# print(pa_list_txt)
# print(pc_list_txt)
# print(pcd_list_txt)
# print(pos_list_txt)
# print(pts_list_txt)

df_temp7 = pd.DataFrame({'공항명(영문)' : eng_list_txt,
                        '공항명(한글)' : kor_list_txt,
                        '주차장명' : pa_list_txt,
                        '주차장혼잡정도' : pc_list_txt,
                        '주차장혼잡률' : pcd_list_txt,
                        '입고된차량수' : pos_list_txt,
                        '전체주차면수' : pts_list_txt})
df_temp7
# Out:
#           공항명(영문) 공항명(한글) 주차장명 주차장혼잡정도  주차장혼잡률 입고된차량수 전체주차면수
# 0  GUNSAN AIRPORT    군산공항   일반      만차  96.08%    343    357

# %%
df_temp_total = pd.concat([df_temp0,df_temp1,df_temp2,df_temp3,df_temp4,df_temp5,df_temp6,df_temp7], ignore_index=True)
df_temp_total
# Out:
#                          공항명(영문) 공항명(한글)         주차장명 주차장혼잡정도  주차장혼잡률 입고된차량수  \
# 0    GIMPO INTERNATIONAL AIRPORT  김포국제공항    [상세]예약주차장      원활  16.87%     56
# 1    GIMPO INTERNATIONAL AIRPORT  김포국제공항    국내선 제1주차장      혼잡  90.22%   2056
# 2    GIMPO INTERNATIONAL AIRPORT  김포국제공항    국내선 제2주차장      원활  87.69%   1531
# 3    GIMPO INTERNATIONAL AIRPORT  김포국제공항     국제선 주차빌딩      원활      0%      0
# 4    GIMPO INTERNATIONAL AIRPORT  김포국제공항    국제선 지하주차장      원활  18.75%    225
# 5    GIMPO INTERNATIONAL AIRPORT  김포국제공항     화물청사 주차장      원활  54.88%    624
# 6   GIMHAE INTERNATIONAL AIRPORT  김해국제공항      P1여객주차장      원활   62.6%   1466
# 7   GIMHAE INTERNATIONAL AIRPORT  김해국제공항      P2여객주차장      원활  61.46%   1102
# 8   GIMHAE INTERNATIONAL AIRPORT  김해국제공항  P3여객(화물)주차장      원활   43.7%    430
# 9   GIMHAE INTERNATIONAL AIRPORT  김해국제공항  P4여객(화물)주차장      원활  69.37%    462
# 10    JEJU INTERNATIONAL AIRPORT  제주국제공항           여객      혼잡  93.98%   1747
# ...

# %% [markdown]
# ## 데이터수집 : 웹 크롤링

# %%
from bs4 import BeautifulSoup as bs

# %%
url = 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EB%82%A0%EC%94%A8'

html = requests.get(url)
soup = bs(html.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
pip install selenium
# Out:
# ...
#      ------------------------------------- 983.2/983.2 KB 10.4 MB/s eta 0:00:00
# ...
#      ------------------------------------- 359.0/359.0 KB 11.3 MB/s eta 0:00:00
# ...
#      ------------------------------------- 180.3/180.3 KB 10.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.4/2.4 MB 17.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.8/55.8 KB 3.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 118.7/118.7 KB 6.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 58.2/58.2 KB 1.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\DEV\Langs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
# 웹 드라이버 라이브러리
from selenium import webdriver

# %%
driver = webdriver.Chrome("C:/ChromeDriver_exe/chromedriver.exe")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12872\2815863721.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:/ChromeDriver_exe/chromedriver.exe")

# %%
driver.get('https://www.naver.com')

# %%
driver.page_source
# Out:
# '<html lang="ko" data-dark="false" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.5005.115 Safari/537.36"><head><script async="" type="text/javascript" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-core.js"></script> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"> <meta name="robots" content="index,nofollow"> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter
# ...
