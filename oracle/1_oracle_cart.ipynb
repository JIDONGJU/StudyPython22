# %%
import cx_Oracle
import pandas as pd

# %%
# 서버 커넥션
dsn = cx_Oracle.makedsn("localhost", 1521, 'orcl')
dsn
# Out:
# '(DESCRIPTION=(ADDRESS=(PROTOCOL=TCP)(HOST=localhost)(PORT=1521))(CONNECT_DATA=(SID=orcl)))'

# %%
conn = cx_Oracle.connect('busan_06', 'dbdb', dsn)
conn
# Out:
# <cx_Oracle.Connection to busan_06@(DESCRIPTION=(ADDRESS=(PROTOCOL=TCP)(HOST=localhost)(PORT=1521))(CONNECT_DATA=(SID=orcl)))>

# %%
cursor = conn.cursor()
cursor
# Out:
# <cx_Oracle.Cursor on <cx_Oracle.Connection to busan_06@(DESCRIPTION=(ADDRESS=(PROTOCOL=TCP)(HOST=localhost)(PORT=1521))(CONNECT_DATA=(SID=orcl)))>>

# %%
sql = '''  Select * from cart '''
sql
# Out:
# '  Select * from cart '

# %%
cursor.execute(sql)
# Out:
# <cx_Oracle.Cursor on <cx_Oracle.Connection to busan_06@(DESCRIPTION=(ADDRESS=(PROTOCOL=TCP)(HOST=localhost)(PORT=1521))(CONNECT_DATA=(SID=orcl)))>>

# %%
row = cursor.fetchall()
row
# Out:
# [('r001', '2005071100002', 'P101000006', 6),
#  ('i001', '2005071900001', 'P102000001', 1),
#  ('i001', '2005071900001', 'P102000002', 2),
#  ('i001', '2005071900001', 'P102000003', 3),
#  ('u001', '2005071900002', 'P102000004', 4),
#  ('u001', '2005071900002', 'P102000005', 5),
#  ('j001', '2005072800001', 'P102000006', 6),
#  ('j001', '2005072800001', 'P102000003', 3),
#  ('q001', '2005072800002', 'P102000004', 4),
#  ('q001', '2005072800002', 'P102000005', 5),
#  ('c001', '2005072800003', 'P301000003', 2),
#  ('c001', '2005072800003', 'P201000015', 2),
#  ('b001', '2005072800004', 'P302000001', 6),
#  ('b001', '2005072800004', 'P201000016', 15),
#  ('b001', '2005072800004', 'P302000002', 2),
#  ('b001', '2005072800004', 'P201000017', 2),
#  ('a001', '2005040100001', 'P101000001', 5),
#  ('a001', '2005040100001', 'P201000018', 16),
#  ('a001', '2005040100001', 'P302000003', 7),
#  ('t001', '2005040100002', 'P302000004', 2),
#  ('t001', '2005040100002', 'P101000002', 2),
# ...

# %%
# 커서가 가진 테이블 정보
colname = cursor.description
colname
# Out:
# [('CART_MEMBER', <cx_Oracle.DbType DB_TYPE_VARCHAR>, 15, 15, None, None, 0),
#  ('CART_NO', <cx_Oracle.DbType DB_TYPE_CHAR>, 13, 13, None, None, 0),
#  ('CART_PROD', <cx_Oracle.DbType DB_TYPE_VARCHAR>, 10, 10, None, None, 0),
#  ('CART_QTY', <cx_Oracle.DbType DB_TYPE_NUMBER>, 9, None, 8, 0, 0)]

# %%
# 접속 끊기
# 순서 꺼꾸로
cursor.close()
conn.close()
# dsn은 안함

# %%
# 컬럼 불러오기
col = []
for tp in colname:
    print(tp[0])
    col.append(tp[0])
col
# Out:
# CART_MEMBER
# CART_NO
# CART_PROD
# CART_QTY
# ['CART_MEMBER', 'CART_NO', 'CART_PROD', 'CART_QTY']

# %%
cart = pd.DataFrame(row, columns=col)
cart
# Out:
#     CART_MEMBER        CART_NO   CART_PROD  CART_QTY
# 0          r001  2005071100002  P101000006         6
# 1          i001  2005071900001  P102000001         1
# 2          i001  2005071900001  P102000002         2
# 3          i001  2005071900001  P102000003         3
# 4          u001  2005071900002  P102000004         4
# ..          ...            ...         ...       ...
# 202        e001  2005070300002  P201000017        21
# 203        g001  2005070800001  P101000001         3
# 204        g001  2005070800001  P101000002         1
# 205        r001  2005070800002  P101000003         2
# 206        h001  2005071100001  P101000005         5
#
# [207 rows x 4 columns]

# %%
'''
-- 전체회원의 2005년도 4월 구매일자에 대한 구매수량의 합을 조회하세요
-- 구매일자는 장바구니 테이블에서 주문번호 앞 8자리입니다
-- 구매수량은 장바구니 테이블에서 수량을 의마합니다.
-- 회원id, 회원성명, 구매수량의 합 조회
-- 구매수량이 없으면 0으로 처리
'''
# Out:
# '\n-- 전체회원의 2005년도 4월 구매일자에 대한 구매수량의 합을 조회하세요\n-- 구매일자는 장바구니 테이블에서 주문번호 앞 8자리입니다\n-- 구매수량은 장바구니 테이블에서 수량을 의마합니다.\n-- 회원id, 회원성명, 구매수량의 합 조회\n-- 구매수량이 없으면 0으로 처리\n'

# %%
# 서버 커넥션
dsn = cx_Oracle.makedsn("localhost", 1521, 'orcl')
dsn
# 테이블이랑 연결하기
conn = cx_Oracle.connect('busan_06', 'dbdb', dsn)
conn
# 커서 생성
cursor = conn.cursor()
cursor
# sql구문으로 값 가져오기
sql = '''  Select * from member '''
sql
# 커서 실행
cursor.execute(sql)
# ??
row = cursor.fetchall()
row
# 커서가 가진 테이블 정보
colname = cursor.description
colname
# 접속 끊기
# 순서 꺼꾸로
cursor.close()
conn.close()
# dsn은 안함
# 컬럼 불러오기
col = []
for tp in colname:
    print(tp[0])
    col.append(tp[0])
col
member = pd.DataFrame(row, columns=col)
member
# Out:
# MEM_ID
# MEM_PASS
# MEM_NAME
# MEM_REGNO1
# MEM_REGNO2
# MEM_BIR
# MEM_ZIP
# MEM_ADD1
# MEM_ADD2
# MEM_HOMETEL
# MEM_COMTEL
# MEM_HP
# MEM_MAIL
# MEM_JOB
# MEM_LIKE
# MEM_MEMORIAL
# MEM_MEMORIALDAY
# MEM_MILEAGE
# MEM_DELETE
#    MEM_ID  MEM_PASS MEM_NAME MEM_REGNO1 MEM_REGNO2    MEM_BIR  MEM_ZIP  \
# 0    a001  asdfasdf      김은대     760115    1406420 1976-01-15  135-972
# 1    b001      1004      이쁜이     741004    2900000 1974-01-07  700-030
# 2    c001      7777      신용환     740124    1400716 1974-01-24  407-817
# 3    d001    123joy      성윤미     460409    2000000 1946-04-09  501-705
# 4    e001  00000000      이혜나     750501    2406017 1975-05-01  617-800
# 5    f001  12345678      신영남     751228    1459919 1972-11-04  140-706
# 6    g001      1456      송경희     771111    2403414 1965-01-01  339-841
# 7    h001      9999      라준호     740728    1455822 1967-03-01  339-841
# 8    i001      1111      최지현     741220    2384719 1974-12-20  306-702
# ...

# %%
'''
-- 전체회원의 2005년도 4월 구매일자에 대한 구매수량의 합을 조회하세요
-- 구매일자는 장바구니 테이블에서 주문번호 앞 8자리입니다
-- 구매수량은 장바구니 테이블에서 수량을 의마합니다.
-- 회원id, 회원성명, 구매수량의 합 조회
-- 구매수량이 없으면 0으로 처리
'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\STUDY\StudyPython22\oracle\1_oracle_cart.ipynb Cell 14' in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/oracle/1_oracle_cart.ipynb#ch0000016?line=0'>1</a> '''
#       <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/oracle/1_oracle_cart.ipynb#ch0000016?line=1'>2</a> -- 전체회원의 2005년도 4월 구매일자에 대한 구매수량의 합을 조회하세요
#       <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/oracle/1_oracle_cart.ipynb#ch0000016?line=2'>3</a> -- 구매일자는 장바구니 테이블에서 주문번호 앞 8자리입니다
#    (...)
#       <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/oracle/1_oracle_cart.ipynb#ch0000016?line=5'>6</a> -- 구매수량이 없으면 0으로 처리
#       <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/oracle/1_oracle_cart.ipynb#ch0000016?line=6'>7</a> '''
# ...
